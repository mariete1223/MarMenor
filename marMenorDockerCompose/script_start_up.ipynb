# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\users\marie\appdata\local\programs\python\python311\lib\site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in c:\users\marie\appdata\local\programs\python\python311\lib\site-packages (from pyarrow) (1.24.4)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
import math

def crear_rambla(id, dateLastValueReported, description, locality, postalCode, source, location, temperature, 
                 providedByTemp, obsTemp, precipitation, providedByPrec, obsPrec, humidity, providedByHum, 
                 obsHum, atmosphericPressure, providedByAtPress, obsAtPress, windDirection, providedByWindDir, 
                 obsWindDir, windSpeed, providedBywindSp, obsWindSp , waterFlowValues, waterLevelValues, 
                 section, nextSection, previousSection, name, measurementsPlaces, volume, providedByVol, obsVol, 
                 pressure, providedByPress, obsPress, conductivity, providedByCond, obsCond):
    rambla_content = {
        "id": f"urn:ngsi-ld:Ravine:{id}",
        "identifier":{
            "type": "Property",
            "value": f"Ravine:{id}"
        },
        "type": "Ravine",
        "dateLastValueReported": {
            "type": "Property",
            "value": dateLastValueReported
        },
        "description": {
            "type": "Property",
            "value": description
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode,
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld"
    }

    # Función auxiliar para agregar una propiedad si no es None
    def add_property_if_not_none(property_name, value, observed_at, unit_code, provided_by):

        singleValues = ["temperature", "precipitation", "humidity","atmosphericPressure", "windDirection", "windSpeed", "volume", "pressure", "conductivity"]

        properties_noneable = [ "section", "nextSection", "previousSection"]
        
            
        if isinstance(value, str):
            rambla_content[property_name] = {
                "type": "Relationship",
                "object": value
            }
        elif value is not None and property_name in singleValues and not math.isnan(value) :
            rambla_content[property_name] = {
                "type": "Property",
                "value": value,
                "observedAt": observed_at,
                "unitCode": unit_code,
                "providedBy": {
                    "type": "Relationship",
                    "object": provided_by
                }
            }
            if (property_name in measurementsPlaces) and  (measurementsPlaces[property_name] is not None):
                rambla_content[property_name]["measurementPlace"] = {
                    "value": measurementsPlaces[property_name]
                }
        elif property_name not in singleValues and value is not None:
            rambla_content[property_name] = {
                "value": value
            }
        elif property_name in singleValues and provided_by is not None and property_name not in properties_noneable:
            rambla_content[property_name] = {
                "type": "Property",
                "value": -99,
                "observedAt": observed_at,
                "unitCode": unit_code,
                "providedBy": {
                    "type": "Relationship",
                    "object": provided_by
                }
            }

            
        

    # Agregar propiedades si no son None
    add_property_if_not_none("temperature", temperature, obsTemp, "CEL", providedByTemp)
    add_property_if_not_none("pressure", pressure, obsPress, "bar", providedByPress)
    add_property_if_not_none("volume", volume, obsVol, "m3", providedByVol)
    add_property_if_not_none("conductivity", conductivity, obsCond, "CEL", providedByCond)
    add_property_if_not_none("windSpeed", windSpeed, obsWindSp, "m/s", providedBywindSp)
    add_property_if_not_none("windDirection", windDirection, obsWindDir, "°", providedByWindDir)
    add_property_if_not_none("atmosphericPressure", atmosphericPressure, obsAtPress, "CEL", providedByAtPress)
    add_property_if_not_none("precipitation", precipitation, obsPrec, "mm", providedByPrec)
    add_property_if_not_none("humidity", humidity, obsHum, "%", providedByHum)
    add_property_if_not_none("waterFlowValues", waterFlowValues, None, "m3/s", None)
    add_property_if_not_none("waterLevelValues", waterLevelValues, None, "m", None)
    add_property_if_not_none("nextSection", nextSection, None, "%", None)
    add_property_if_not_none("previousSection", previousSection, None, "m3/s", None)
    add_property_if_not_none("section", section, None, "m3/s", None)

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }

    print("*"*15)
    print(rambla_content)
    print(providedByPress)
    
    response = requests.post(url, headers=headers, json=rambla_content)

# %%
def crear_sensor(id, sensor_type, locality, postalCode, location, controlledProperty, measuredProperty, measureValue , unitCode, source, controlledAsset, dateLastValueReported, measureType):
    sensor_content = {
        "id": f"urn:ngsi-ld:{sensor_type}:{id}",
        "identifier":{
            "type": "Property",
            "value": f"{sensor_type}:{id}"
        },
        "type": sensor_type,
        "category": {
            "type": "Property",
            "value": "sensor"
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "controlledProperty": {
            "type": "Property",
            "value": controlledProperty
        },
        measuredProperty: {
            "type": "Property",
            "value": measureValue,
            "observedAt": dateLastValueReported,
            "unitCode": unitCode
        },
        "measureType": {
            "type": "Property",
            "value": measureType
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "controlledAsset": {
            "type": "Relationship",
            "object": controlledAsset
        },
        "@context": "https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld"
    }
    
    if unitCode is None:
        del sensor_content[measuredProperty]["unitCode"]
        
    
    if measureType == "multipleValue":
        del sensor_content[measuredProperty]
        if (measureValue is not None):
            sensor_content[measuredProperty+"Values"] =[measureValue]
        else:
            sensor_content[measuredProperty+"Values"] = [[{"depth": {"value": -99, "unitCode": "MTR"}, "value": {"value": -99, "unitCode": "CEL"}, "observedAt": dateLastValueReported}]]
    else:
        if measureValue is None or (measureValue == "-" or math.isnan(measureValue)):
            sensor_content[measuredProperty]["value"] = -99

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }
    response = requests.post(url, headers=headers, json=sensor_content)
    print(sensor_content)
    print(response)
    if(response.status_code == 409):
        print(f"urn:ngsi-ld:{sensor_type}:{id}")

# %%
import math

def crear_piezometro(id, locality, postalCode, location, description, source, dateLastValueReported, numberInNetwork,
                      temperature, obsTemp, providedByTemp, conductivity, obsCond, providedByCond,
                      piezometricLevel, obsPiez, providedByPiez, salinity, obsSal, providedBySal,
                      tds, obsTDS, providedByTDS, name):

    piezometer_content = {
        "id": f"urn:ngsi-ld:PiezometricPoint:{id}",
        "identifier":{
            "type": "Property",
            "value": f"PiezometricPoint:{id}"
        },
        "type": "PiezometricPoint",
        "category": {
            "type": "Property",
            "value": "sensor"
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "description": {
            "type": "Property",
            "value": description
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "dateLastValueReported": {
            "type": "Property",
            "value": dateLastValueReported
        },
        "numberInNetwork": {
            "type": "Property",
            "value": 1
        },
         "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld"
    }

    # Función auxiliar para agregar una propiedad si no es None
    def add_property_if_not_none(property_name, value, observed_at, unit_code, provided_by):
        if value is not None and not math.isnan(value) :
            piezometer_content[property_name] = {
                "type": "Property",
                "value": value,
                "observedAt": observed_at,
                "unitCode": unit_code,
                "providedBy": {
                    "type": "Relationship",
                    "object": provided_by
                }
            }
        else:
            piezometer_content[property_name] = {
                "type": "Property",
                "value": -99,
                "observedAt": observed_at,
                "unitCode": unit_code,
                "providedBy": {
                    "type": "Relationship",
                    "object": provided_by
                }
            }

    # Agregar propiedades si no son None
    add_property_if_not_none("temperature", temperature, obsTemp, "CEL", providedByTemp)
    add_property_if_not_none("conductivity", conductivity, obsCond, "µS/cm", providedByCond)
    add_property_if_not_none("piezometricLevel", piezometricLevel, obsPiez, "msnm", providedByPiez)
    add_property_if_not_none("salinity", salinity, obsSal, "PSU", providedBySal)
    add_property_if_not_none("tds", tds, obsTDS, "mg/L", providedByTDS)

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }


    response = requests.post(url, headers=headers, json=piezometer_content)
    print(piezometer_content)
    print(response)

# %%
import requests
import json

def crear_boya(id, dateLastValueReported, description, postalCode, locality, location, name, source, temperatureValues=None, chlorophyllValues=None, conductivityValues=None, organicMatterValues=None, oxygenValues=None, pHValues=None, polyethyleneValues=None, salinityValues=None, transparencyValues=None, turbidityValues=None, closeMeasurements=None):
    buoy_content = {
        "id": f"urn:ngsi-ld:Buoy:{id}",
        "identifier":{
            "type": "Property",
            "value":  f"Buoy:{id}"
        },
        "type": "Buoy",
        "dateLastValueReported": {
            "type": "Property",
            "value": dateLastValueReported
        },
        "description": {
            "type": "Property",
            "value": description
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode
            },
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "temperatureValues": {
            "type": "Property",
            "value": [temperatureValues]},
        "chlorophyllValues": {
            "type": "Property",
            "value":[chlorophyllValues]},
        "conductivityValues": {
            "type": "Property",
            "value":[conductivityValues]},
        "organicMatterValues": {
            "type": "Property",
            "value":[organicMatterValues]},
        "oxygenValues": {
            "type": "Property",
            "value":[oxygenValues]},
        "pHValues": {
            "type": "Property",
            "value":[pHValues]},
        "polyethyleneValues": {
            "type": "Property",
            "value":[polyethyleneValues]},
        "salinityValues": {
            "type": "Property",
            "value":[salinityValues]},
        "transparencyValues": {
            "type": "Property",
            "value":[transparencyValues]
        },
        "turbidityValues": {
            "type": "Property",
            "value":turbidityValues
        },
        "closeMeasurements": closeMeasurements,

        "@context": "https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld"
    }
    
    if temperatureValues is None:
        del buoy_content["temperatureValues"]
    if chlorophyllValues is None:
        del buoy_content["chlorophyllValues"]
    if conductivityValues is None:
        del buoy_content["conductivityValues"]
    if organicMatterValues is None:
        del buoy_content["organicMatterValues"]
    if oxygenValues is None:
        del buoy_content["oxygenValues"]
    if pHValues is None:
        del buoy_content["pHValues"]
    if polyethyleneValues is None:
        del buoy_content["polyethyleneValues"]
    if salinityValues is None:
        del buoy_content["salinityValues"]
    if transparencyValues is None:
        del buoy_content["transparencyValues"]
    if turbidityValues is None:
        del buoy_content["turbidityValues"]
    if closeMeasurements is None:
        del buoy_content["closeMeasurements"]

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }

    try:
        response = requests.post(url, headers=headers, json=buoy_content)
        response.raise_for_status()  # Lanza una excepción para códigos de estado HTTP no exitosos
    except requests.exceptions.RequestException as e:
        print(f"Error creating entity: {e}")

# %%
def crear_subscription(description, entity_type, watched_attributes, sent_attributes, query, url):
    subscription_content = {
        "description": description,
        "type": "Subscription",
        "entities": [{"type": entity_type}],
        "watchedAttributes": watched_attributes,
        "notification": {
            "attributes": sent_attributes,
            "format": "normalized",
            "endpoint": {
                "uri": url,
                "accept":  "application/json"
            }
        },
        "@context": "https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld"
    }

    def add_property_if_not_none(property_name, query):
        if query is not None:
            subscription_content[property_name] = query

    # Agregar propiedades si no son None
    add_property_if_not_none("q", query)

    url = "http://localhost:1026/ngsi-ld/v1/subscriptions/"

    headers = {
        "Content-Type": "application/ld+json"
    }

    response = requests.post(url, headers=headers, json=subscription_content)
    print(subscription_content)
    print(response)

# %%
def modify_entity( value, observedAt, url, multipleValue = None, place = None):

    headers = {
        'Content-Type': 'application/json',
        'Link': '<https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

    print(value)
    if isinstance(value, float) and  math.isnan(value):
        value = -99

    if multipleValue is not None:
        modify_content = {
        "value": [multipleValue]
        }
    elif observedAt is not None and place is not None:
        modify_content = {
        "value": value,
        "observedAt": observedAt,
        "measurementPlace": {
            "value": place
            }
        }
    elif observedAt is not None:
        modify_content = {
        "value": value,
        "observedAt": observedAt
        }
    elif place is not None:
        modify_content = {
        "value": value,
        "measurementPlace": {
            "value": place
            }
        }
    else:       
        modify_content = {
            "value": value,
        }

    print("modify_content")
    print(modify_content)
    response = requests.patch(url, headers=headers, json=modify_content)
    print(response.status_code)
    try:
        if response.status_code != 204:
            print(response.text)
    finally:
        response.close()

# %%
def create_attribute(newAttributeName, value, observedAt, url, multipleValue = None):

    headers = {
        'Content-Type': 'application/json',
        'Link': '<https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

    if multipleValue is not None:
        modify_content = {
            newAttributeName: {
                 "value": [multipleValue]
            }
        }
    elif observedAt is None:
        modify_content = {
            newAttributeName: {
                "value": value
            }
        }
    else:       
        modify_content = {
            newAttributeName: {
                "value": value,
                "observedAt": observedAt
            }
        }

    response = requests.post(url, headers=headers, json=modify_content)
    try:
        if response.status_code != 204:
            print(response.text)
    finally:
        response.close()

# %%
def search_close_entities(coordinate_lat,coordinate_long, id_entity):
    url = 'http://localhost:1026/ngsi-ld/v1/entities'
    headers = {
        'Accept': 'application/json',
        'Link': '<https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

    params = {
        'geometry': 'Point',
        'coordinates': f'[{coordinate_lat},{coordinate_long}]',
        'georel': 'near;maxDistance==4000',
        'options': 'keyValues',
    }

    response = requests.get(url, headers=headers, params=params)

    data = response.json()
    filtered_data = [entity.get("id",) for entity in data if ('Sensor' not in entity.get('id', '')) and (id_entity not in entity.get('id', '') )]
    return filtered_data

# %%
entities_id = {}

# %%
import os
import glob
import pandas as pd
import pyarrow.parquet as pq



carpeta = "C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/piezometros/"
# Especifica la ruta de la carpeta principal
#carpeta = "C:\\Users\\marie\\OneDrive\\Escritorio\\Antiguo ordenador\\Universidad\\Master 1º\\TFM\\NGSI-LD\\datos\\SAIHdatasActualizados\\piezometros\\"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}


# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    df_total = pd.DataFrame()
    archivos_parquet = glob.glob(os.path.join(carpeta+carpeta_actual, "*.parquet"))
    #archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))
    for archivo in archivos_parquet:
    
        #df_temporal = pd.read_csv(archivo)
        df_temporal = pd.read_parquet(archivo)
        df_temporal.to_csv(archivo.split(".")[0]+"from_parquet.csv", index=False)
        tabla = pq.ParquetFile(archivo)
        #pq.write_table(tabla, "ejemplo.parquet", version='1.0')
        # Imprime la versión del archivo Parquet
        print(tabla.metadata)
        print("-"*10)
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="inner")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")
# Out:
# <pyarrow._parquet.FileMetaData object at 0x000001EA9A967420>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAE354F650>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9D5677E0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADCF2B6F0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAF1B0CAE0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA126C040>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9D55D850>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1571
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADF7F0A90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1567
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAE3548090>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD86E3A10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA3C0B600>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9C978F90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA90453FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1567
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD86E00E0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1689
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA920E2DE0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA3C0B600>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA87CEBFB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1567
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAF1B3ED90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADCF2A610>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1689
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAE5D40090>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1547
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAEA5BD8A0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1555
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADCF2A610>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1551
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAFA9E7F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1527
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA85A180E0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1675
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA859FFF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA85A18310>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAE5D40090>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD953FF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1542
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD953FA60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAFA9E7F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA843A7D30>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD953FF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA837F8F40>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1542
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA859FF0B0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9C28FD80>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA859FFF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA885A0360>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9C28FD80>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1540
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA919DBF10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA885A1490>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1560
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAEA5BC310>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA8F1ABF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA917E9E90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1540
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA8C75FD30>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAFA9E7F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1561
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA92A67C90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA95C2BFB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA919DBBF0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1540
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA919D8950>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA95C28770>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1560
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA95C2BCE0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA919D8540>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA97127D80>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD953FA60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9A1A7FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAEA5BF6F0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9DDA98A0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9AA0E250>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAAF64E430>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1689
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA1628F90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADCF2B6F0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9EDABFB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA162B790>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1542
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA917EBF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAEA5BE1B0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA917EBF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1571
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAEAB460C0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1567
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA6A66C00>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADB0CFF10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1689
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAD8D3FFB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1546
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA843A7C40>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1554
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAE5D43970>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1550
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAAF490EA0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1527
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADB0CFD80>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 45216
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1674
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA7A08130>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1561
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAA7A08450>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAFA9E7F10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADB0CC360>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1541
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA920E0E50>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1689
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADB0CFF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1560
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA920E0E50>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADBE5BFB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADBD77DD0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1540
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAFA9E7F10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1688
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADF4EBF10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADAE4FF10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADB17E250>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1566
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EAE4507FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1542
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADBD77F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADB17C0E0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADBD77F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1571
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EA9C28C040>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1567
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADBD77F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x000001EADEA13FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 436272
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1691
# ----------

# %%
dfs["06Z02-Sondeo02"]
# Out:
#                         Date  Temperatura  Conductividad  Piezometrico  \
# 0       2019-12-13T00:00:00Z          NaN            NaN           NaN
# 1       2019-12-13T00:05:00Z          NaN            NaN           NaN
# 2       2019-12-13T00:10:00Z          NaN            NaN           NaN
# 3       2019-12-13T00:15:00Z          NaN            NaN           NaN
# 4       2019-12-13T00:20:00Z          NaN            NaN           NaN
# ...                      ...          ...            ...           ...
# 436267  2024-02-04T23:35:00Z        22.86         1220.0         1.049
# 436268  2024-02-04T23:40:00Z        22.86         1220.0         1.049
# 436269  2024-02-04T23:45:00Z        22.86         1220.0         1.049
# 436270  2024-02-04T23:50:00Z        22.86         1220.0         1.049
# 436271  2024-02-04T23:55:00Z        22.86         1220.0         1.049
#
#         Salinidad  Total solido disuelto (TDS)
# 0             NaN                          NaN
# 1             NaN                          NaN
# 2             NaN                          NaN
# 3             NaN                          NaN
# 4             NaN                          NaN
# ...           ...                          ...
# 436267        NaN                        780.0
# 436268        NaN                        780.0
# 436269        NaN                        780.0
# 436270        NaN                        780.0
# 436271        NaN                        780.0
#
# [436272 rows x 6 columns]

# %%
diccionario_info_piezometros = {
    "06Z01": {
        "locality": "Calle de Murillo, Los Belones, Cartagena",
        "postalCode": "30385",
        "location": [37.630082, -0.777017],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10",
    },
    "06Z02": {
        "locality": "F-34, Cartagena",
        "postalCode": "30383",
        "location": [37.642663, -0.777275],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10",
    },
    "06Z03": {
        "locality": "Camino Rural XVIII, El Algar, Cartagena",
        "postalCode": "30366",
        "location": [37.654261, -0.848734],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10",
    },
    "06Z05": {
        "locality": "N-332, Cartagena",
        "postalCode": "30368",
        "location": [37.6841, -0.8692],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10",
    },
    "06Z06": {
        "locality": "N-332, Cartagena",
        "postalCode": "30368",
        "location": [ 37.7058, -0.8633],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10",
    },
    "06Z07": {
        "locality": "Camino Rural XIII, El Algar, Cartagena",
        "postalCode": "30395",
        "location": [37.7104, -0.8879],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10",
    },
    "06Z08": {
        "locality": "F-35, Cartagena",
        "postalCode": "30710",
        "location": [37.7511, -0.8828],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z08E10",
    },
    "06Z09": {
        "locality": "Autopista del Mediterraneo, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.7452, -0.8679],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z09E10",
    },
    "06Z10": {
        "locality": "Cartagena",
        "postalCode": "30710",
        "location": [37.7618, -0.8673],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z10E10",
    },
    "06Z11": {
        "locality": "Avenida de Muñoz Zambudio, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.7543, -0.8588],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10",
    },
    "06Z12": {
        "locality": "Calle Bergantin, San Javier, Cartagena",
        "postalCode": "30739",
        "location": [37.7755, -0.8514],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10",
    },
    "06Z13": {
        "locality": "Calle de Poseidon, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.7696, -0.8385],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z13E10",
    },
    "06Z14": {
        "locality": "N-332, San Javier, Cartagena",
        "postalCode": "30730",
        "location": [37.7883, -0.8387],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10",
    },
    "06Z15": {
        "locality": "Cartagena",
        "postalCode": "30730",
        "location": [37.7802, -0.8302],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z15E10",
    },
    "06Z16": {
        "locality": "Calle del Embalse de la Toba, San Javier, Cartagena",
        "postalCode": "30730",
        "location": [37.8181, -0.8286],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10",
    },
    "06Z17": {
        "locality": "Avenida de la Romeria de San Blas 2, San Javier, Cartagena",
        "postalCode": "30720",
        "location": [37.8059, -0.8168],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z17E10",
    },
    "06Z18": {
        "locality": "Autopista del Mediterraneo, San Javier, Cartagena",
        "postalCode": "30730",
        "location": [37.8247, -0.8165],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z18E10",
    },
    "06Z19": {
        "locality": "Calle de Navacerrada 33, San Javier, Cartagena",
        "postalCode": "30720",
        "location": [37.8178, -0.8085],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z19E10",
    },
    "06Z20": {
        "locality": "Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena",
        "postalCode": "30740",
        "location": [37.8350, -0.8023],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10",
    },
}

# %%
def uploadFileRead(id_sensor, filePath, controlledProperty, controlledCsvHeader, unitCode, entity_id, measureType):

    payload = {
        "measureType": measureType,
        "sensorId": id_sensor,
        "file": filePath,
        "controlledProperty": controlledProperty,
        "controlledCsvHeader": controlledCsvHeader,
        "unitCode": unitCode
    }
    
    url = f"http://localhost:3000/historic/uploadFile/{entity_id}"

    headers = {
        "Content-Type": "application/json"
    }

    response = requests.post(url, headers=headers, json=payload)
    print(response.status_code)

# %%
def uploadHistoric_node_app(id_sensor, sensor_name, value, unitCode, observedAt, property_name, id_entity):

    payload ={
    "notifiedAt": "2024-02-13T07:23:48.435Z",
    "data": [
        {
            "id": id_sensor,
            "type": sensor_name,
            property_name: {
                "type": "Property",
                "value": value,
                "unitCode": unitCode,
                "observedAt": observedAt
            },
            "measureType": {
                "type": "Property",
                "value": "singleValue"
            },
            "controlledAsset": {
                "type": "Relationship",
                "object": id_entity
            }
        }
    ]
}
    
    url = f"http://localhost:3000/historic/{id_sensor}"

    headers = {
        "Content-Type": "application/json"
    }
    response = requests.post(url, headers=headers, json=payload)

# %%
entities_id = {}

# %%
import math
import time

def check_exists(place_to_search, value_to_search, array=False):
    if array:
        return place_to_search[value_to_search][0] if value_to_search in place_to_search else None

    return place_to_search[value_to_search] if value_to_search in place_to_search else None

maper_property_sensor = { "Temperatura": "TemperatureSensor", "Conductividad": "ConductivitySensor", "Piezometrico":"PiezometricLevelSensor", "Salinidad":"SalinitySensor",
       "Total solido disuelto (TDS)": "TdsSensor"
}

maper_property_filename = { "Temperatura": "E01-Temperaturafrom_parquet.csv", "Conductividad": "E03-Conductividadfrom_parquet.csv", "Piezometrico":"E10-Piezometricofrom_parquet.csv", "Salinidad":"E11-Salinidadfrom_parquet.csv",
        "Total solido disuelto (TDS)": "E12-Total solido disuelto (TDS)from_parquet.csv"}

maper_property_controlled = { "Temperatura": "temperature", "Conductividad": "conductivity", "Piezometrico":"piezometricLevel", "Salinidad":"salinity",
       "Total solido disuelto (TDS)": "tds"
}

maper_property_unitcode = { "Temperatura": "CEL", "Conductividad": "microseconds/cm", "Piezometrico":"msnm", "Salinidad":"PSU",
       "Total solido disuelto (TDS)": "mg/l"
}

link_piezometro_sensores = {}

num_piezometros = 0


counter_connections = 0
counters = {}
for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = valorCarpeta.columns
    for i in sensores:
        if counters.get(i) is None:
            counters[i] = 0
    id_entity = f"urn:ngsi-ld:PiezometricPoint:{str(num_piezometros).zfill(3)}"
    number_entity = str(num_piezometros).zfill(3)
    id_piezometro = carpeta.split("-")[0]
    for index, row in valorCarpeta.iterrows():
        print(counter_connections)
        counter_connections = counter_connections + 1
        if index == 0:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
            
                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[sensores[contador]]}:{str(counters[valorSensor]).zfill(3)}"
                print(row["Date"])
                crear_sensor(
                        id=str(counters[valorSensor]).zfill(3),
                        sensor_type=maper_property_sensor[sensores[contador]],
                        locality=diccionario_info_piezometros[id_piezometro]["locality"],
                        postalCode=diccionario_info_piezometros[id_piezometro]["postalCode"],
                        location=diccionario_info_piezometros[id_piezometro]["location"],
                        measureType="singleValue",
                        controlledProperty=maper_property_controlled[valorSensor],
                        measuredProperty=maper_property_controlled[valorSensor],
                        measureValue=row[valorSensor],
                        unitCode=maper_property_unitcode[valorSensor],
                        source=diccionario_info_piezometros[id_piezometro]["source"],
                        controlledAsset=id_entity,
                        dateLastValueReported=row["Date"],
                )
                    
                if id_entity not in link_piezometro_sensores:
                    link_piezometro_sensores[id_entity] = {}
                link_piezometro_sensores[id_entity][valorSensor] = id_sensor,
                crear_subscription(
                        description="Subscription to get info about " + id_entity + " sensor",
                        entity_type=maper_property_sensor[sensores[contador]],
                        watched_attributes=[maper_property_controlled[valorSensor]],
                        sent_attributes=[maper_property_controlled[valorSensor], "controlledAsset", "measureType"],
                        # TODO Cambiar Id por identifier aqui y en el modelo NGSI-LD y en el required
                        query=f"identifier==%22{maper_property_sensor[sensores[contador]]}:{str(counters[valorSensor]).zfill(3)}%22",
                        url="http://node-app:3000/historic/"+id_sensor
                )
                counters[valorSensor]+=1
            entities_id[id_entity] = diccionario_info_piezometros[id_piezometro]["location"]
            crear_piezometro(
                id=number_entity,
                locality=diccionario_info_piezometros[id_piezometro]["locality"],
                postalCode=diccionario_info_piezometros[id_piezometro]["postalCode"],
                location=diccionario_info_piezometros[id_piezometro]["location"],
                description="Piezometric Point "+ id_piezometro +" which belong to the piezometric net in Mar Menor",
                source=diccionario_info_piezometros[id_piezometro]["source"],
                dateLastValueReported=row["Date"],
                numberInNetwork=id_piezometro.split("Z")[1],
                temperature=check_exists(row,"Temperatura"),
                obsTemp=row["Date"],
                providedByTemp=check_exists(link_piezometro_sensores[id_entity],"Temperatura",array=True),
                conductivity=check_exists(row,"Conductividad"),
                obsCond=row["Date"],
                providedByCond=check_exists(link_piezometro_sensores[id_entity],"Conductividad",array=True),
                piezometricLevel=check_exists(row,"Piezometrico"),
                obsPiez=row["Date"],
                providedByPiez=check_exists(link_piezometro_sensores[id_entity],"Piezometrico",array=True),
                salinity=check_exists(row,"Salinidad"),
                obsSal=row["Date"],
                providedBySal=check_exists(link_piezometro_sensores[id_entity],"Salinidad",array=True),
                tds=check_exists(row,"Total solido disuelto (TDS)"),
                obsTDS=row["Date"],
                providedByTDS=check_exists(link_piezometro_sensores[id_entity],"Total solido disuelto (TDS)",array=True),
                name="Piezometric Point "+id_piezometro,
            )
            num_piezometros += 1
        elif index == 1:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    print(row["Date"])
                    continue
                print(valorSensor)
                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[sensores[contador]]}:{str((counters[valorSensor]-1)).zfill(3)}"

                file = id_piezometro+maper_property_filename[valorSensor]
                uploadFileRead(id_sensor, "piezometros/"+carpeta+"/"+file, maper_property_controlled[valorSensor], valorSensor, maper_property_unitcode[valorSensor], id_entity, "singleValue")
        else:
            time.sleep(30)
            break
# Out:
# 06Z01-Sondeo01
# 0
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TemperatureSensor:000', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:000'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Murillo, Los Belones, Cartagena', 'postalCode': '30385'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.630082, -0.777017]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 22.14, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:000'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:000 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:000%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:ConductivitySensor:000', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:000'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Murillo, Los Belones, Cartagena', 'postalCode': '30385'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.630082, -0.777017]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'conductivity': {'type': 'Property', 'value': 3350.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:000'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:000 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivity'], 'notification': {'attributes': ['conductivity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:000%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:PiezometricLevelSensor:000', 'identifier': {'type': 'Property', 'value': 'PiezometricLevelSensor:000'}, 'type': 'PiezometricLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Murillo, Los Belones, Cartagena', 'postalCode': '30385'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.630082, -0.777017]}}, 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'piezometricLevel': {'type': 'Property', 'value': 3.541, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:000'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:000 sensor', 'type': 'Subscription', 'entities': [{'type': 'PiezometricLevelSensor'}], 'watchedAttributes': ['piezometricLevel'], 'notification': {'attributes': ['piezometricLevel', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PiezometricLevelSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PiezometricLevelSensor:000%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:SalinitySensor:000', 'identifier': {'type': 'Property', 'value': 'SalinitySensor:000'}, 'type': 'SalinitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Murillo, Los Belones, Cartagena', 'postalCode': '30385'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.630082, -0.777017]}}, 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:000'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:000 sensor', 'type': 'Subscription', 'entities': [{'type': 'SalinitySensor'}], 'watchedAttributes': ['salinity'], 'notification': {'attributes': ['salinity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:SalinitySensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22SalinitySensor:000%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TdsSensor:000', 'identifier': {'type': 'Property', 'value': 'TdsSensor:000'}, 'type': 'TdsSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Murillo, Los Belones, Cartagena', 'postalCode': '30385'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.630082, -0.777017]}}, 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'tds': {'type': 'Property', 'value': 2140.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/l'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:000'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:000 sensor', 'type': 'Subscription', 'entities': [{'type': 'TdsSensor'}], 'watchedAttributes': ['tds'], 'notification': {'attributes': ['tds', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TdsSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TdsSensor:000%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PiezometricPoint:000', 'identifier': {'type': 'Property', 'value': 'PiezometricPoint:000'}, 'type': 'PiezometricPoint', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Murillo, Los Belones, Cartagena', 'postalCode': '30385'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.630082, -0.777017]}}, 'description': {'type': 'Property', 'value': 'Piezometric Point 06Z01 which belong to the piezometric net in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numberInNetwork': {'type': 'Property', 'value': 1}, 'name': {'type': 'Property', 'value': 'Piezometric Point 06Z01'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 22.14, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:000'}}, 'conductivity': {'type': 'Property', 'value': 3350.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'µS/cm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:ConductivitySensor:000'}}, 'piezometricLevel': {'type': 'Property', 'value': 3.541, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricLevelSensor:000'}}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:SalinitySensor:000'}}, 'tds': {'type': 'Property', 'value': 2140.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/L', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TdsSensor:000'}}}
# <Response [201]>
# 1
# 2019-12-13T00:05:00Z
# Temperatura
# 204
# Conductividad
# 204
# Piezometrico
# 204
# Salinidad
# 204
# Total solido disuelto (TDS)
# 204
# 2
# 06Z02-Sondeo02
# 3
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TemperatureSensor:001', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:001'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-34, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.642663, -0.777275]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:001%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:ConductivitySensor:001', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:001'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-34, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.642663, -0.777275]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'conductivity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivity'], 'notification': {'attributes': ['conductivity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:001%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:PiezometricLevelSensor:001', 'identifier': {'type': 'Property', 'value': 'PiezometricLevelSensor:001'}, 'type': 'PiezometricLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-34, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.642663, -0.777275]}}, 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'piezometricLevel': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'PiezometricLevelSensor'}], 'watchedAttributes': ['piezometricLevel'], 'notification': {'attributes': ['piezometricLevel', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PiezometricLevelSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PiezometricLevelSensor:001%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:SalinitySensor:001', 'identifier': {'type': 'Property', 'value': 'SalinitySensor:001'}, 'type': 'SalinitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-34, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.642663, -0.777275]}}, 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'SalinitySensor'}], 'watchedAttributes': ['salinity'], 'notification': {'attributes': ['salinity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:SalinitySensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22SalinitySensor:001%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TdsSensor:001', 'identifier': {'type': 'Property', 'value': 'TdsSensor:001'}, 'type': 'TdsSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-34, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.642663, -0.777275]}}, 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'tds': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/l'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'TdsSensor'}], 'watchedAttributes': ['tds'], 'notification': {'attributes': ['tds', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TdsSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TdsSensor:001%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PiezometricPoint:001', 'identifier': {'type': 'Property', 'value': 'PiezometricPoint:001'}, 'type': 'PiezometricPoint', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-34, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.642663, -0.777275]}}, 'description': {'type': 'Property', 'value': 'Piezometric Point 06Z02 which belong to the piezometric net in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numberInNetwork': {'type': 'Property', 'value': 1}, 'name': {'type': 'Property', 'value': 'Piezometric Point 06Z02'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:001'}}, 'conductivity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'µS/cm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:ConductivitySensor:001'}}, 'piezometricLevel': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricLevelSensor:001'}}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:SalinitySensor:001'}}, 'tds': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/L', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TdsSensor:001'}}}
# <Response [201]>
# 4
# 2019-12-13T00:05:00Z
# Temperatura
# 204
# Conductividad
# 204
# Piezometrico
# 204
# Salinidad
# 204
# Total solido disuelto (TDS)
# 204
# 5
# 06Z03-Sondeo03
# 6
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TemperatureSensor:002', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:002'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XVIII, El Algar, Cartagena', 'postalCode': '30366'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.654261, -0.848734]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 20.65, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:002', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:002%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:ConductivitySensor:002', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:002'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XVIII, El Algar, Cartagena', 'postalCode': '30366'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.654261, -0.848734]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'conductivity': {'type': 'Property', 'value': 2020.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivity'], 'notification': {'attributes': ['conductivity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:002', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:002%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:PiezometricLevelSensor:002', 'identifier': {'type': 'Property', 'value': 'PiezometricLevelSensor:002'}, 'type': 'PiezometricLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XVIII, El Algar, Cartagena', 'postalCode': '30366'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.654261, -0.848734]}}, 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'piezometricLevel': {'type': 'Property', 'value': 20.979, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'PiezometricLevelSensor'}], 'watchedAttributes': ['piezometricLevel'], 'notification': {'attributes': ['piezometricLevel', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PiezometricLevelSensor:002', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PiezometricLevelSensor:002%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TdsSensor:002', 'identifier': {'type': 'Property', 'value': 'TdsSensor:002'}, 'type': 'TdsSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XVIII, El Algar, Cartagena', 'postalCode': '30366'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.654261, -0.848734]}}, 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'tds': {'type': 'Property', 'value': 1290.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/l'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'TdsSensor'}], 'watchedAttributes': ['tds'], 'notification': {'attributes': ['tds', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TdsSensor:002', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TdsSensor:002%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PiezometricPoint:002', 'identifier': {'type': 'Property', 'value': 'PiezometricPoint:002'}, 'type': 'PiezometricPoint', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XVIII, El Algar, Cartagena', 'postalCode': '30366'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.654261, -0.848734]}}, 'description': {'type': 'Property', 'value': 'Piezometric Point 06Z03 which belong to the piezometric net in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numberInNetwork': {'type': 'Property', 'value': 1}, 'name': {'type': 'Property', 'value': 'Piezometric Point 06Z03'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 20.65, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:002'}}, 'conductivity': {'type': 'Property', 'value': 2020.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'µS/cm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:ConductivitySensor:002'}}, 'piezometricLevel': {'type': 'Property', 'value': 20.979, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricLevelSensor:002'}}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU', 'providedBy': {'type': 'Relationship', 'object': None}}, 'tds': {'type': 'Property', 'value': 1290.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/L', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TdsSensor:002'}}}
# <Response [400]>
# 7
# 2019-12-13T00:05:00Z
# Temperatura
# 204
# Conductividad
# 204
# Piezometrico
# 204
# Total solido disuelto (TDS)
# 204
# 8
# 06Z05-Sondeo05
# 9
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TemperatureSensor:003', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:003'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 21.44, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:003', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:003%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:ConductivitySensor:003', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:003'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'conductivity': {'type': 'Property', 'value': 6240.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivity'], 'notification': {'attributes': ['conductivity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:003', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:003%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:PiezometricLevelSensor:003', 'identifier': {'type': 'Property', 'value': 'PiezometricLevelSensor:003'}, 'type': 'PiezometricLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'piezometricLevel': {'type': 'Property', 'value': 8.541, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'PiezometricLevelSensor'}], 'watchedAttributes': ['piezometricLevel'], 'notification': {'attributes': ['piezometricLevel', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PiezometricLevelSensor:003', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PiezometricLevelSensor:003%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:SalinitySensor:002', 'identifier': {'type': 'Property', 'value': 'SalinitySensor:002'}, 'type': 'SalinitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'salinity': {'type': 'Property', 'value': 3.69, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'SalinitySensor'}], 'watchedAttributes': ['salinity'], 'notification': {'attributes': ['salinity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:SalinitySensor:002', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22SalinitySensor:002%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TdsSensor:003', 'identifier': {'type': 'Property', 'value': 'TdsSensor:003'}, 'type': 'TdsSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'tds': {'type': 'Property', 'value': 3990.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/l'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'TdsSensor'}], 'watchedAttributes': ['tds'], 'notification': {'attributes': ['tds', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TdsSensor:003', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TdsSensor:003%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PiezometricPoint:003', 'identifier': {'type': 'Property', 'value': 'PiezometricPoint:003'}, 'type': 'PiezometricPoint', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'description': {'type': 'Property', 'value': 'Piezometric Point 06Z05 which belong to the piezometric net in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numberInNetwork': {'type': 'Property', 'value': 1}, 'name': {'type': 'Property', 'value': 'Piezometric Point 06Z05'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 21.44, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:003'}}, 'conductivity': {'type': 'Property', 'value': 6240.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'µS/cm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:ConductivitySensor:003'}}, 'piezometricLevel': {'type': 'Property', 'value': 8.541, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricLevelSensor:003'}}, 'salinity': {'type': 'Property', 'value': 3.69, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:SalinitySensor:002'}}, 'tds': {'type': 'Property', 'value': 3990.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/L', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TdsSensor:003'}}}
# <Response [201]>
# 10
# 2019-12-13T00:05:00Z
# Temperatura
# 204
# Conductividad
# 204
# Piezometrico
# 204
# Salinidad
# 204
# Total solido disuelto (TDS)
# 204
# 11
# 06Z06-Sondeo06
# 12
# 2023-09-01T00:00:00Z
# {'id': 'urn:ngsi-ld:TemperatureSensor:004', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:004'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7058, -0.8633]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:004', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:004%22'}
# <Response [201]>
# 2023-09-01T00:00:00Z
# {'id': 'urn:ngsi-ld:ConductivitySensor:004', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:004'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7058, -0.8633]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'conductivity': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivity'], 'notification': {'attributes': ['conductivity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:004', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:004%22'}
# <Response [201]>
# 2023-09-01T00:00:00Z
# {'id': 'urn:ngsi-ld:PiezometricLevelSensor:004', 'identifier': {'type': 'Property', 'value': 'PiezometricLevelSensor:004'}, 'type': 'PiezometricLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7058, -0.8633]}}, 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'piezometricLevel': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z', 'unitCode': 'msnm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'PiezometricLevelSensor'}], 'watchedAttributes': ['piezometricLevel'], 'notification': {'attributes': ['piezometricLevel', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PiezometricLevelSensor:004', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PiezometricLevelSensor:004%22'}
# <Response [201]>
# 2023-09-01T00:00:00Z
# ...
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:017 sensor', 'type': 'Subscription', 'entities': [{'type': 'SalinitySensor'}], 'watchedAttributes': ['salinity'], 'notification': {'attributes': ['salinity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:SalinitySensor:016', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22SalinitySensor:016%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TdsSensor:017', 'identifier': {'type': 'Property', 'value': 'TdsSensor:017'}, 'type': 'TdsSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Navacerrada 33, San Javier, Cartagena', 'postalCode': '30720'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8178, -0.8085]}}, 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'tds': {'type': 'Property', 'value': 3750.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/l'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z19E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:017'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:017 sensor', 'type': 'Subscription', 'entities': [{'type': 'TdsSensor'}], 'watchedAttributes': ['tds'], 'notification': {'attributes': ['tds', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TdsSensor:017', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TdsSensor:017%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PiezometricPoint:017', 'identifier': {'type': 'Property', 'value': 'PiezometricPoint:017'}, 'type': 'PiezometricPoint', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle de Navacerrada 33, San Javier, Cartagena', 'postalCode': '30720'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8178, -0.8085]}}, 'description': {'type': 'Property', 'value': 'Piezometric Point 06Z19 which belong to the piezometric net in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z19E10'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numberInNetwork': {'type': 'Property', 'value': 1}, 'name': {'type': 'Property', 'value': 'Piezometric Point 06Z19'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 20.87, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:017'}}, 'conductivity': {'type': 'Property', 'value': 5850.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'µS/cm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:ConductivitySensor:017'}}, 'piezometricLevel': {'type': 'Property', 'value': 10.797, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricLevelSensor:017'}}, 'salinity': {'type': 'Property', 'value': 3.49, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:SalinitySensor:016'}}, 'tds': {'type': 'Property', 'value': 3750.0, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/L', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TdsSensor:017'}}}
# <Response [201]>
# 52
# 2019-12-13T00:05:00Z
# Temperatura
# 204
# Conductividad
# 204
# Piezometrico
# 204
# Salinidad
# 204
# Total solido disuelto (TDS)
# 204
# 53
# 06Z20-Sondeo20
# 54
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TemperatureSensor:018', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:018'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:018'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:018 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:018', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:018%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:ConductivitySensor:018', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:018'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'conductivity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:018'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:018 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivity'], 'notification': {'attributes': ['conductivity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:018', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:018%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:PiezometricLevelSensor:018', 'identifier': {'type': 'Property', 'value': 'PiezometricLevelSensor:018'}, 'type': 'PiezometricLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'piezometricLevel': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:018'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:018 sensor', 'type': 'Subscription', 'entities': [{'type': 'PiezometricLevelSensor'}], 'watchedAttributes': ['piezometricLevel'], 'notification': {'attributes': ['piezometricLevel', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PiezometricLevelSensor:018', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PiezometricLevelSensor:018%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:SalinitySensor:017', 'identifier': {'type': 'Property', 'value': 'SalinitySensor:017'}, 'type': 'SalinitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:018'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:018 sensor', 'type': 'Subscription', 'entities': [{'type': 'SalinitySensor'}], 'watchedAttributes': ['salinity'], 'notification': {'attributes': ['salinity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:SalinitySensor:017', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22SalinitySensor:017%22'}
# <Response [201]>
# 2019-12-13T00:00:00Z
# {'id': 'urn:ngsi-ld:TdsSensor:018', 'identifier': {'type': 'Property', 'value': 'TdsSensor:018'}, 'type': 'TdsSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'tds': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/l'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricPoint:018'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:PiezometricPoint:018 sensor', 'type': 'Subscription', 'entities': [{'type': 'TdsSensor'}], 'watchedAttributes': ['tds'], 'notification': {'attributes': ['tds', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TdsSensor:018', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TdsSensor:018%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PiezometricPoint:018', 'identifier': {'type': 'Property', 'value': 'PiezometricPoint:018'}, 'type': 'PiezometricPoint', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'description': {'type': 'Property', 'value': 'Piezometric Point 06Z20 which belong to the piezometric net in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numberInNetwork': {'type': 'Property', 'value': 1}, 'name': {'type': 'Property', 'value': 'Piezometric Point 06Z20'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:018'}}, 'conductivity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'µS/cm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:ConductivitySensor:018'}}, 'piezometricLevel': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'msnm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricLevelSensor:018'}}, 'salinity': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'PSU', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:SalinitySensor:017'}}, 'tds': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z', 'unitCode': 'mg/L', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TdsSensor:018'}}}
# <Response [201]>
# 55
# 2019-12-13T00:05:00Z
# Temperatura
# 204
# Conductividad
# 204
# Piezometrico
# 204
# Salinidad
# 204
# Total solido disuelto (TDS)
# 204
# 56

# %%
import os
import glob
import pandas as pd
import pyarrow.parquet as pq

carpeta = "C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/piezometros/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}


# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    df_total = pd.DataFrame()
    archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))

    archivos_csv = [archivo for archivo in archivos_csv if "parquet" not in archivo]
    for archivo in archivos_csv:
    
        df_temporal = pd.read_csv(archivo)

        if(len(df_total) == 0):
            df_total = df_temporal
        else:

            df_total = pd.merge(df_total, df_temporal, on="Date", how="inner")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")

# %%
import math
import time

def check_exists(place_to_search, value_to_search, array=False):
    if array:
        return place_to_search[value_to_search][0] if value_to_search in place_to_search else None

    return place_to_search[value_to_search] if value_to_search in place_to_search else None

maper_property_sensor = { "Temperatura": "TemperatureSensor", "Conductividad": "ConductivitySensor", "Piezometrico":"PiezometricLevelSensor", "Salinidad":"SalinitySensor",
       "Total solido disuelto (TDS)": "TdsSensor"
}

maper_property_filename = { "Temperatura": "E01-Temperatura.parquet", "Conductividad": "E03-Conductividad.parquet", "Piezometrico":"E10-Piezometrico.parquet", "Salinidad":"E11-Salinidad.parquet",
        "Total solido disuelto (TDS)": "E12-Total solido disuelto (TDS).parquet"}

maper_property_controlled = { "Temperatura": "temperature", "Conductividad": "conductivity", "Piezometrico":"piezometricLevel", "Salinidad":"salinity",
       "Total solido disuelto (TDS)": "tds"
}

maper_property_unitcode = { "Temperatura": "CEL", "Conductividad": "microseconds/cm", "Piezometrico":"msnm", "Salinidad":"PSU",
       "Total solido disuelto (TDS)": "mg/l"
}

link_piezometro_sensores = {}

num_piezometros = 0


counter_connections = 0
for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = valorCarpeta.columns
    for i in sensores:
        if counters.get(i) is None:
            counters[i] = 0
    id_entity = f"urn:ngsi-ld:PiezometricPoint:{str(num_piezometros).zfill(3)}"
    number_entity = str(num_piezometros).zfill(3)
    id_piezometro = carpeta.split("-")[0]
    counter_connections = counter_connections + 1

    for contador,valorSensor in enumerate(sensores):
        if valorSensor == "Date":
            continue
        id_sensor = f"urn:ngsi-ld:{maper_property_sensor[sensores[contador]]}:{str((counters[valorSensor]-1)).zfill(3)}"

        last_value = valorCarpeta[valorSensor].iloc[-1]
        last_date = valorCarpeta["Date"].iloc[-1]
        
        modify_entity(
            value=last_value,
            observedAt=last_date,
            url="http://localhost:1026/ngsi-ld/v1/entities/"+id_sensor+"/attrs/"+maper_property_controlled[valorSensor]
        )
        modify_entity(
            value=last_date,
            observedAt=None,
            url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/dateLastValueReported"
        )
        modify_entity(
            value=last_value,
            observedAt=last_date,
            url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/"+maper_property_controlled[valorSensor]
        )

        time.sleep(1)
    num_piezometros += 1
# Out:
# 06Z01-Sondeo01
# 22.22
# modify_content
# {'value': 22.22, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 22.22
# modify_content
# {'value': 22.22, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3860.0
# modify_content
# {'value': 3860.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3860.0
# modify_content
# {'value': 3860.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 1.841
# modify_content
# {'value': 1.841, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 1.841
# modify_content
# {'value': 1.841, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2.18
# modify_content
# {'value': 2.18, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2.18
# modify_content
# {'value': 2.18, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2470.0
# modify_content
# {'value': 2470.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2470.0
# modify_content
# {'value': 2470.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z02-Sondeo02
# 22.9
# modify_content
# {'value': 22.9, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 22.9
# modify_content
# {'value': 22.9, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 1210.0
# modify_content
# {'value': 1210.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 1210.0
# modify_content
# {'value': 1210.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 1.029
# modify_content
# {'value': 1.029, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 1.029
# modify_content
# {'value': 1.029, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# nan
# modify_content
# {'value': -99, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# nan
# modify_content
# {'value': -99, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 770.0
# modify_content
# {'value': 770.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 770.0
# modify_content
# {'value': 770.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z03-Sondeo03
# 20.76
# modify_content
# {'value': 20.76, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 20.76
# modify_content
# {'value': 20.76, 'observedAt': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 1870.0
# modify_content
# {'value': 1870.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 1870.0
# modify_content
# {'value': 1870.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 17.149
# modify_content
# {'value': 17.149, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 17.149
# modify_content
# {'value': 17.149, 'observedAt': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 1190.0
# modify_content
# {'value': 1190.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 1190.0
# modify_content
# {'value': 1190.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 404
# {"type":"https://uri.etsi.org/ngsi-ld/errors/ResourceNotFound","title":"Entity/Attribute Not Found","detail":"urn:ngsi-ld:PiezometricPoint:002"}
# 06Z05-Sondeo05
# 21.47
# modify_content
# {'value': 21.47, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.47
# modify_content
# {'value': 21.47, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4930.0
# modify_content
# {'value': 4930.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4930.0
# modify_content
# {'value': 4930.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 8.291
# modify_content
# {'value': 8.291, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 8.291
# modify_content
# {'value': 8.291, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2.87
# modify_content
# {'value': 2.87, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2.87
# modify_content
# {'value': 2.87, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3150.0
# modify_content
# {'value': 3150.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3150.0
# modify_content
# {'value': 3150.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z06-Sondeo06
# 21.65
# modify_content
# {'value': 21.65, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.65
# modify_content
# {'value': 21.65, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 15510.0
# modify_content
# {'value': 15510.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 15510.0
# modify_content
# {'value': 15510.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 9.1
# modify_content
# {'value': 9.1, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 9.1
# modify_content
# {'value': 9.1, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 9930.0
# modify_content
# {'value': 9930.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 9930.0
# modify_content
# {'value': 9930.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z07-Sondeo07
# 20.3
# modify_content
# {'value': 20.3, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.3
# modify_content
# {'value': 20.3, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 7290.0
# modify_content
# {'value': 7290.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 7290.0
# modify_content
# {'value': 7290.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 9.035
# modify_content
# {'value': 9.035, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 9.035
# modify_content
# {'value': 9.035, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4.47
# modify_content
# {'value': 4.47, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4.47
# modify_content
# {'value': 4.47, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4670.0
# modify_content
# {'value': 4670.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4670.0
# modify_content
# {'value': 4670.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z08-Sondeo08
# 20.21
# modify_content
# {'value': 20.21, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.21
# modify_content
# {'value': 20.21, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 10680.0
# modify_content
# {'value': 10680.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 10680.0
# modify_content
# {'value': 10680.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 15.971
# modify_content
# {'value': 15.971, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 15.971
# modify_content
# {'value': 15.971, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6.75
# modify_content
# {'value': 6.75, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6.75
# modify_content
# {'value': 6.75, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6830.0
# modify_content
# {'value': 6830.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6830.0
# modify_content
# {'value': 6830.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z09-Sondeo09
# 20.24
# modify_content
# {'value': 20.24, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.24
# modify_content
# {'value': 20.24, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 8550.0
# modify_content
# {'value': 8550.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 8550.0
# modify_content
# {'value': 8550.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 8.774
# modify_content
# {'value': 8.774, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 8.774
# modify_content
# {'value': 8.774, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 5.31
# modify_content
# {'value': 5.31, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 5.31
# modify_content
# {'value': 5.31, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 5470.0
# modify_content
# {'value': 5470.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 5470.0
# modify_content
# {'value': 5470.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z10-Sondeo10
# 21.46
# modify_content
# {'value': 21.46, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.46
# modify_content
# {'value': 21.46, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6350.0
# modify_content
# {'value': 6350.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6350.0
# modify_content
# {'value': 6350.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 14.153
# modify_content
# {'value': 14.153, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 14.153
# modify_content
# {'value': 14.153, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3.76
# modify_content
# {'value': 3.76, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3.76
# modify_content
# {'value': 3.76, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4060.0
# modify_content
# {'value': 4060.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4060.0
# modify_content
# {'value': 4060.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z11-Sondeo11
# 20.66
# modify_content
# {'value': 20.66, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.66
# modify_content
# {'value': 20.66, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 8270.0
# modify_content
# {'value': 8270.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 8270.0
# modify_content
# {'value': 8270.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 8.296
# modify_content
# {'value': 8.296, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 8.296
# modify_content
# {'value': 8.296, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 5.07
# modify_content
# {'value': 5.07, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 5.07
# modify_content
# {'value': 5.07, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 5290.0
# modify_content
# {'value': 5290.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 5290.0
# modify_content
# {'value': 5290.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z12-Sondeo12
# 21.17
# modify_content
# {'value': 21.17, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.17
# modify_content
# {'value': 21.17, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4060.0
# modify_content
# {'value': 4060.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4060.0
# modify_content
# {'value': 4060.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 13.44
# modify_content
# {'value': 13.44, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 13.44
# modify_content
# {'value': 13.44, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2.35
# modify_content
# {'value': 2.35, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2.35
# modify_content
# {'value': 2.35, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2600.0
# modify_content
# {'value': 2600.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2600.0
# modify_content
# {'value': 2600.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z13-Sondeo13
# 20.55
# modify_content
# {'value': 20.55, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.55
# modify_content
# {'value': 20.55, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 7420.0
# modify_content
# {'value': 7420.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 7420.0
# modify_content
# {'value': 7420.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6.85
# modify_content
# {'value': 6.85, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6.85
# modify_content
# {'value': 6.85, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4.53
# modify_content
# {'value': 4.53, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4.53
# modify_content
# {'value': 4.53, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4750.0
# modify_content
# {'value': 4750.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4750.0
# modify_content
# {'value': 4750.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z14-Sondeo14
# 21.9
# modify_content
# {'value': 21.9, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.9
# modify_content
# {'value': 21.9, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 5750.0
# modify_content
# {'value': 5750.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 5750.0
# modify_content
# {'value': 5750.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 13.011
# modify_content
# {'value': 13.011, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 13.011
# modify_content
# {'value': 13.011, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3.35
# modify_content
# {'value': 3.35, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3.35
# modify_content
# {'value': 3.35, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3680.0
# modify_content
# {'value': 3680.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3680.0
# modify_content
# {'value': 3680.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z15-Sondeo15
# 21.02
# modify_content
# {'value': 21.02, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.02
# modify_content
# {'value': 21.02, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4490.0
# modify_content
# {'value': 4490.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4490.0
# modify_content
# {'value': 4490.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6.976
# modify_content
# {'value': 6.976, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6.976
# modify_content
# {'value': 6.976, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2.62
# modify_content
# {'value': 2.62, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2.62
# modify_content
# {'value': 2.62, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2870.0
# modify_content
# {'value': 2870.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2870.0
# modify_content
# {'value': 2870.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z16-Sondeo16
# 20.93
# modify_content
# {'value': 20.93, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.93
# modify_content
# {'value': 20.93, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 7050.0
# modify_content
# {'value': 7050.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 7050.0
# modify_content
# {'value': 7050.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 17.721
# modify_content
# {'value': 17.721, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 17.721
# modify_content
# {'value': 17.721, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3.9
# modify_content
# {'value': 3.9, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3.9
# modify_content
# {'value': 3.9, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4510.0
# modify_content
# {'value': 4510.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4510.0
# modify_content
# {'value': 4510.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z17-Sondeo17
# 21.32
# modify_content
# {'value': 21.32, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.32
# modify_content
# {'value': 21.32, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6820.0
# modify_content
# {'value': 6820.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6820.0
# modify_content
# {'value': 6820.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 9.211
# modify_content
# {'value': 9.211, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 9.211
# modify_content
# {'value': 9.211, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4.07
# modify_content
# {'value': 4.07, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4.07
# modify_content
# {'value': 4.07, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4360.0
# modify_content
# {'value': 4360.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4360.0
# modify_content
# {'value': 4360.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z18-Sondeo18
# 21.71
# modify_content
# {'value': 21.71, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.71
# modify_content
# {'value': 21.71, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4920.0
# modify_content
# {'value': 4920.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4920.0
# modify_content
# {'value': 4920.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 16.76
# modify_content
# {'value': 16.76, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 16.76
# modify_content
# {'value': 16.76, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2.85
# modify_content
# {'value': 2.85, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2.85
# modify_content
# {'value': 2.85, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3150.0
# modify_content
# {'value': 3150.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3150.0
# modify_content
# {'value': 3150.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z19-Sondeo19
# 20.94
# modify_content
# {'value': 20.94, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 20.94
# modify_content
# {'value': 20.94, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 6290.0
# modify_content
# {'value': 6290.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 6290.0
# modify_content
# {'value': 6290.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 9.617
# modify_content
# {'value': 9.617, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 9.617
# modify_content
# {'value': 9.617, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 3.77
# modify_content
# {'value': 3.77, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 3.77
# modify_content
# {'value': 3.77, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4030.0
# modify_content
# {'value': 4030.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4030.0
# modify_content
# {'value': 4030.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 06Z20-Sondeo20
# 21.63
# modify_content
# {'value': 21.63, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 21.63
# modify_content
# {'value': 21.63, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 4070.0
# modify_content
# {'value': 4070.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 4070.0
# modify_content
# {'value': 4070.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 10.981
# modify_content
# {'value': 10.981, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 10.981
# modify_content
# {'value': 10.981, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2.33
# modify_content
# {'value': 2.33, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2.33
# modify_content
# {'value': 2.33, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2600.0
# modify_content
# {'value': 2600.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204
# 2024-02-12T02:00:00Z
# modify_content
# {'value': '2024-02-12T02:00:00Z'}
# 204
# 2600.0
# modify_content
# {'value': 2600.0, 'observedAt': '2024-02-12T02:00:00Z'}
# 204

# %%
diccionario_info_boyas = {
    "E1": {
        "locality": "Mar Menor, San Javier, Cartagena",
        "postalCode": "30380",
        "location": [37.81, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1",
    },
    "E2": {
        "locality": "Mar Menor, Playa de la Hita, Cartagena",
        "postalCode": "30380",
        "location": [37.76, -0.8],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E2",
    },
    "E3": {
        "locality": "Mar Menor, Playa de la Hita, Cartagena",
        "postalCode": "30380",
        "location": [37.76, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3",
    },
    "E4": {
        "locality": "Mar Menor, La Manga, Cartagena",
        "postalCode": "30380",
        "location": [37.74, -0.74],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E4",
    },
    "E5": {
        "locality": "Mar Menor, La Manga, Cartagena",
        "postalCode": "30380",
        "location": [37.74, -0.72],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E5",
    },
    "E6": {
        "locality": "Mar Menor, Isla Mayor, Cartagena",
        "postalCode": "30720",
        "location": [37.71, -0.77],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E6",
    },
    "E7": {
        "locality": "Mar Menor, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.71, -0.83],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E7",
    },
    "E8": {
        "locality": "Mar Menor, Los Urrutias, Cartagena",
        "postalCode": "30368",
        "location": [37.69, -0.81],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E8",
    },
    "E9": {
        "locality": "Mar Menor, Saladar de Lo Poyo, Cartagena",
        "postalCode": "30368",
        "location": [37.66, -0.8],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9",
    },
    "E10": {
        "locality": "Mar Menor, Los Nietos, Cartagena",
        "postalCode": "30383",
        "location": [37.65, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E10",
    },
    "E11": {
        "locality": "Mar Menor, La Manga, Cartagena",
        "postalCode": "30380",
        "location": [37.65, -0.72],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E11",
    },
    "E12": {
        "locality": "Mar Menor, Cartagena",
        "postalCode": "30380",
        "location": [37.68, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E12",
    },
}

# %%
import os
import glob
import pandas as pd
import time

# Especifica la ruta de la carpeta principal
carpeta = "C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/BoyasProf/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}

# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    print(carpeta_actual)
    df_total = pd.DataFrame()
    archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))
    for archivo in archivos_csv:
        
        nombre_archivo = archivo.split("\\")[-1].split(".")[0]
        df_temporal = pd.read_csv(archivo)
        columna_date = df_temporal.pop('Date')
        # Insertar la columna "Date" al principio
        df_temporal.insert(0, 'Date', columna_date)
        df_temporal.to_csv(archivo, index=False)
# Out:
# CTD-E1
# CTD-E10
# CTD-E11
# CTD-E12
# CTD-E2
# CTD-E3
# CTD-E4
# CTD-E5
# CTD-E6
# CTD-E7
# CTD-E8
# CTD-E9

# %%
import os
import glob
import pandas as pd
import time

# Especifica la ruta de la carpeta principal
carpeta = "C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/BoyasProf/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}

# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    print(carpeta_actual)
    df_total = pd.DataFrame()
    archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))
    for archivo in archivos_csv:
        
        nombre_archivo = archivo.split("\\")[-1].split(".")[0]
        df_temporal = pd.read_csv(archivo)
        df_temporal.columns = [df_temporal.columns[0]] + [f"{nombre_archivo}_{col.split('_')[1]}" for col in df_temporal.columns[1:]]
        df_temporal = df_temporal.loc[:, ~df_temporal.columns.str.contains("None")]
        
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="inner")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")
# Out:
# CTD-E1
# CTD-E10
# CTD-E11
# CTD-E12
# CTD-E2
# CTD-E3
# CTD-E4
# CTD-E5
# CTD-E6
# CTD-E7
# CTD-E8
# CTD-E9

# %%
import math
import time
import re

def formatMultipleValues(values, depths, unitcode, observedAt, providedBy):
    if len(values) == 0:
        return None
    else:
        result = []
        for i in range(len(values)):
            json_data = {
                "measure": {
                    "value": values[i],
                    "unitCode": unitcode
                },
                "depth": {
                    "value": float(depths[i]),
                    "unitCode": "MTR"
                },
                "providedBy": providedBy,
                "observedAt": observedAt
            }
            if providedBy is None:
                del json_data["providedBy"]
            if unitcode is None:
                del json_data["measure"]["unitCode"]
            result.append(json_data)
        return result

maper_property_sensor = { "Clorofila":"ChlorophyllSensor","PH":"PhSensor","Polietileno":"PolyethyleneSensor","Turbidez":"TurbiditySensor","Salinidad":"SalinitySensor",
        "Transparencia":"TransparencySensor","Oxigeno":"OxygenSensor","Temperatura": "TemperatureSensor", "Conductividad": "ConductivitySensor", "Piezometrico":"PiezometricLevelSensor", 
        "Total solido disuelto (TDS)": "TdsSensor", "Materia Organiza":"OrganicMatterSensor"
}

maper_property_controlled = { "Temperatura": "temperature","Materia Organiza":"OrganicMatterSensor", "Conductividad": "conductivity", "Piezometrico":"piezometricLevel", "Salinidad":"salinity",
       "Total solido disuelto (TDS)": "tds", "Clorofila":"chlorophyll","PH":"pH","Polietileno":"polyethylene","Turbidez":"turbidity","Transparencia":"transparency","Oxigeno":"oxygen"
}

maper_property_unitcode = { "Temperatura": "CEL", "Conductividad": "microseconds/cm", "Piezometrico":"msnm", "Salinidad":"PSU",
       "Total solido disuelto (TDS)": "mg/l", "Materia Organiza":None,"Clorofila":None,"PH":"pH",
       "Polietileno":None,"Turbidez":"NTU","Transparencia":None,"Oxigeno":None
}

link_piezometro_sensores = {}

num_boyas = 0

counter_connections = 0

for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    for i in sensores:
        if counters.get(i) is None:
            counters[i] = 0
    
    id_boya = carpeta.split("-")[1]
    number_entity = str(id_boya[1:]).zfill(3)
    id_entity = f"urn:ngsi-ld:Buoy:{number_entity}"
    for index, row in valorCarpeta.iterrows():
        counter_connections = counter_connections + 1
        if index == 0:
            measuredValues = {}
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[sensores[contador]]}:{str(counters[valorSensor]).zfill(3)}"
                try:
                    profundidades, valores = zip(*((col.split("_")[1], row[col]) for col in valorCarpeta.columns if col.startswith(valorSensor) and not pd.isna(row[col]) ))
                except ValueError:
                    profundidades = []
                    valores = []
                profundidades = list(profundidades)
                valores = list(valores)
                measuredValues[valorSensor] = formatMultipleValues(valores,profundidades, maper_property_unitcode[valorSensor], row["Date"], None)
                crear_sensor(
                     id=str(counters[valorSensor]).zfill(3),
                     sensor_type=maper_property_sensor[sensores[contador]],
                     locality=diccionario_info_boyas[id_boya]["locality"],
                     postalCode=diccionario_info_boyas[id_boya]["postalCode"],
                     location=diccionario_info_boyas[id_boya]["location"],
                     controlledProperty=maper_property_controlled[valorSensor],
                     measuredProperty=maper_property_controlled[valorSensor],
                     measureType="multipleValue",
                     measureValue=measuredValues[valorSensor],
                     unitCode=maper_property_unitcode[valorSensor],
                     source=diccionario_info_boyas[id_boya]["source"],
                     controlledAsset=id_entity,
                     dateLastValueReported=row["Date"],
                )
                    
                if id_entity not in link_piezometro_sensores:
                    link_piezometro_sensores[id_entity] = {}
                link_piezometro_sensores[id_entity][valorSensor] = id_sensor,
                crear_subscription(
                    description="Subscription to get info about " + id_entity + " sensor",
                    entity_type=maper_property_sensor[sensores[contador]],
                    watched_attributes=[maper_property_controlled[valorSensor]+"Values"],
                    sent_attributes=[maper_property_controlled[valorSensor]+"Values", "controlledAsset", "measureType"],
                    # TODO Cambiar Id por identifier aqui y en el modelo NGSI-LD y en el required
                    query=f"identifier==%22{maper_property_sensor[sensores[contador]]}:{str(counters[valorSensor]).zfill(3)}%22",
                    url="http://node-app:3000/historic/"+id_sensor
                )
                counters[valorSensor]+=1
                
            # Añadimos el providedBy
            
            for key, json_object in measuredValues.items():
                if json_object is not None:
                    for value in json_object:
                        value.update({"providedBy": link_piezometro_sensores[id_entity][key][0]})
            # Cambiar a crear Boya aqui
            entities_id[id_entity] = diccionario_info_boyas[id_boya]["location"]
            crear_boya(
                id=number_entity,
                dateLastValueReported=row["Date"],
                description="Buoy "+ id_boya +" for measuring water quality in the Mar Menor",
                postalCode=diccionario_info_boyas[id_boya]["postalCode"],
                location=diccionario_info_boyas[id_boya]["location"],
                locality=diccionario_info_boyas[id_boya]["locality"],
                name="Buoy " + number_entity,
                source=diccionario_info_boyas[id_boya]["source"],
                temperatureValues=measuredValues["Temperatura"], 
                chlorophyllValues=measuredValues["Clorofila"], 
                conductivityValues=measuredValues["Conductividad"], 
                organicMatterValues=measuredValues["Materia Organiza"],
                oxygenValues=measuredValues["Oxigeno"], 
                pHValues=measuredValues["PH"], 
                polyethyleneValues=measuredValues["Polietileno"], 
                salinityValues=measuredValues["Salinidad"], 
                transparencyValues=measuredValues["Transparencia"], 
                turbidityValues=measuredValues["Turbidez"], 
            )
            num_boyas += 1
        elif index == 1:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    print(row["Date"])
                    continue

                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[sensores[contador]]}:{str((counters[valorSensor]-1)).zfill(3)}"

                file = valorSensor+".csv"
                columnas = [col for col in valorCarpeta.columns if col.startswith(valorSensor)]
                pattern = re.compile(r'^.*?_(.*?)$')

                # Nueva lista con las sustituciones
                columnas = [re.sub(pattern, r'profundidad_\1', header) for header in columnas]
                print(columnas)
                uploadFileRead(id_sensor, "BoyasProf/"+carpeta+"/"+file, maper_property_controlled[valorSensor], columnas, maper_property_unitcode[valorSensor], id_entity, "multipleValue")
        elif index == 2:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[sensores[contador]]}:{str((counters[valorSensor]-1)).zfill(3)}"

                try:
                    profundidades, valores = zip(*((col.split("_")[1], valorCarpeta[col].iloc[-1]) for col in valorCarpeta.columns if col.startswith(valorSensor) and not pd.isna(valorCarpeta[col].iloc[-1]) ))
                except ValueError:
                    profundidades = []
                    valores = []
                profundidades = list(profundidades)
                valores = list(valores)
                last_date = valorCarpeta["Date"].iloc[-1]
                last_value = formatMultipleValues(valores,profundidades, maper_property_unitcode[valorSensor], last_date, None)

                
                
                if last_value is None:
                    last_value = []

                print(last_value)   
                print(last_date)
                print("http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/"+maper_property_controlled[valorSensor]+"Values")
                modify_entity(
                    multipleValue=last_value,
                    value=None,
                    observedAt=None,
                    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_sensor+"/attrs/"+maper_property_controlled[valorSensor]+"Values",
                )
                modify_entity(
                    value=last_date,
                    observedAt=None,
                    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/dateLastValueReported"
                )
                modify_entity(
                    multipleValue=last_value,
                    value=None,
                    observedAt=None,
                    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/"+maper_property_controlled[valorSensor]+"Values",
                )
        else:
            time.sleep(30)
            break
# Out:
# CTD-E1
# {'id': 'urn:ngsi-ld:TurbiditySensor:008', 'identifier': {'type': 'Property', 'value': 'TurbiditySensor:008'}, 'type': 'TurbiditySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'turbidity'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'turbidityValues': [[{'measure': {'value': 5.33, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 5.63, 'unitCode': 'NTU'}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 5.84, 'unitCode': 'NTU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [409]>
# urn:ngsi-ld:TurbiditySensor:008
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'TurbiditySensor'}], 'watchedAttributes': ['turbidityValues'], 'notification': {'attributes': ['turbidityValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TurbiditySensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TurbiditySensor:008%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:SalinitySensor:026', 'identifier': {'type': 'Property', 'value': 'SalinitySensor:026'}, 'type': 'SalinitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'salinityValues': [[{'measure': {'value': 45.62, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 45.57, 'unitCode': 'PSU'}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 45.57, 'unitCode': 'PSU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'SalinitySensor'}], 'watchedAttributes': ['salinityValues'], 'notification': {'attributes': ['salinityValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:SalinitySensor:026', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22SalinitySensor:026%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:TemperatureSensor:027', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:027'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperatureValues': [[{'measure': {'value': 28.63, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 28.61, 'unitCode': 'CEL'}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 28.55, 'unitCode': 'CEL'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperatureValues'], 'notification': {'attributes': ['temperatureValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:027', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:027%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:ConductivitySensor:027', 'identifier': {'type': 'Property', 'value': 'ConductivitySensor:027'}, 'type': 'ConductivitySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'conductivityValues': [[{'measure': {'value': 71.86, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 71.75, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 71.67, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'ConductivitySensor'}], 'watchedAttributes': ['conductivityValues'], 'notification': {'attributes': ['conductivityValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ConductivitySensor:027', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ConductivitySensor:027%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:OxygenSensor:008', 'identifier': {'type': 'Property', 'value': 'OxygenSensor:008'}, 'type': 'OxygenSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'oxygen'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'oxygenValues': [[{'measure': {'value': 5.38}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 4.57}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 4.35}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'OxygenSensor'}], 'watchedAttributes': ['oxygenValues'], 'notification': {'attributes': ['oxygenValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:OxygenSensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22OxygenSensor:008%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PhSensor:008', 'identifier': {'type': 'Property', 'value': 'PhSensor:008'}, 'type': 'PhSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'pHValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'PhSensor'}], 'watchedAttributes': ['pHValues'], 'notification': {'attributes': ['pHValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PhSensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PhSensor:008%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:ChlorophyllSensor:008', 'identifier': {'type': 'Property', 'value': 'ChlorophyllSensor:008'}, 'type': 'ChlorophyllSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'chlorophyll'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'chlorophyllValues': [[{'measure': {'value': 12.87}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 11.91}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 11.78}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'ChlorophyllSensor'}], 'watchedAttributes': ['chlorophyllValues'], 'notification': {'attributes': ['chlorophyllValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ChlorophyllSensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ChlorophyllSensor:008%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:OrganicMatterSensor:008', 'identifier': {'type': 'Property', 'value': 'OrganicMatterSensor:008'}, 'type': 'OrganicMatterSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'OrganicMatterSensor'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'OrganicMatterSensorValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'OrganicMatterSensor'}], 'watchedAttributes': ['OrganicMatterSensorValues'], 'notification': {'attributes': ['OrganicMatterSensorValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:OrganicMatterSensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22OrganicMatterSensor:008%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PolyethyleneSensor:008', 'identifier': {'type': 'Property', 'value': 'PolyethyleneSensor:008'}, 'type': 'PolyethyleneSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'polyethylene'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'polyethyleneValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'PolyethyleneSensor'}], 'watchedAttributes': ['polyethyleneValues'], 'notification': {'attributes': ['polyethyleneValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PolyethyleneSensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PolyethyleneSensor:008%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:TransparencySensor:008', 'identifier': {'type': 'Property', 'value': 'TransparencySensor:008'}, 'type': 'TransparencySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, San Javier, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.81, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'transparencyValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'TransparencySensor'}], 'watchedAttributes': ['transparencyValues'], 'notification': {'attributes': ['transparencyValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TransparencySensor:008', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TransparencySensor:008%22'}
# <Response [201]>
# Error creating entity: 409 Client Error: Conflict for url: http://localhost:1026/ngsi-ld/v1/entities/
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# 2016-08-04T00:00:00Z
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0', 'profundidad_-0.4', 'profundidad_-0.8', 'profundidad_-1.2000000000000002', 'profundidad_-1.6']
# 204
# [{'measure': {'value': 0.48, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.67, 'unitCode': 'NTU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.45, 'unitCode': 'NTU'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.45, 'unitCode': 'NTU'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.51, 'unitCode': 'NTU'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.56, 'unitCode': 'NTU'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/turbidityValues
# None
# modify_content
# {'value': [[{'measure': {'value': 0.48, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.67, 'unitCode': 'NTU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.45, 'unitCode': 'NTU'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.45, 'unitCode': 'NTU'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.51, 'unitCode': 'NTU'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.56, 'unitCode': 'NTU'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 0.48, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.67, 'unitCode': 'NTU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.45, 'unitCode': 'NTU'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.45, 'unitCode': 'NTU'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.51, 'unitCode': 'NTU'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.56, 'unitCode': 'NTU'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 43.78, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.9, 'unitCode': 'PSU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.85, 'unitCode': 'PSU'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/salinityValues
# None
# modify_content
# {'value': [[{'measure': {'value': 43.78, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.9, 'unitCode': 'PSU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.85, 'unitCode': 'PSU'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 43.78, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.9, 'unitCode': 'PSU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.85, 'unitCode': 'PSU'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 43.75, 'unitCode': 'PSU'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 30.86, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.8, 'unitCode': 'CEL'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.63, 'unitCode': 'CEL'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.64, 'unitCode': 'CEL'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.76, 'unitCode': 'CEL'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.64, 'unitCode': 'CEL'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/temperatureValues
# None
# modify_content
# {'value': [[{'measure': {'value': 30.86, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.8, 'unitCode': 'CEL'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.63, 'unitCode': 'CEL'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.64, 'unitCode': 'CEL'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.76, 'unitCode': 'CEL'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.64, 'unitCode': 'CEL'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 30.86, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.8, 'unitCode': 'CEL'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.63, 'unitCode': 'CEL'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.64, 'unitCode': 'CEL'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.76, 'unitCode': 'CEL'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 30.64, 'unitCode': 'CEL'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 7.22, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.23, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.22, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/conductivityValues
# None
# modify_content
# {'value': [[{'measure': {'value': 7.22, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.23, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.22, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 7.22, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.23, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.22, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 4.75}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 5.81}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.56}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.58}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 5.08}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.53}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/oxygenValues
# None
# modify_content
# {'value': [[{'measure': {'value': 4.75}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 5.81}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.56}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.58}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 5.08}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.53}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 4.75}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 5.81}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.56}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.58}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 5.08}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 4.53}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 8.71, 'unitCode': 'pH'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.73, 'unitCode': 'pH'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.69, 'unitCode': 'pH'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.68, 'unitCode': 'pH'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.71, 'unitCode': 'pH'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.68, 'unitCode': 'pH'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/pHValues
# None
# modify_content
# {'value': [[{'measure': {'value': 8.71, 'unitCode': 'pH'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.73, 'unitCode': 'pH'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.69, 'unitCode': 'pH'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.68, 'unitCode': 'pH'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.71, 'unitCode': 'pH'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.68, 'unitCode': 'pH'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 8.71, 'unitCode': 'pH'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.73, 'unitCode': 'pH'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.69, 'unitCode': 'pH'}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.68, 'unitCode': 'pH'}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.71, 'unitCode': 'pH'}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.68, 'unitCode': 'pH'}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 0.3}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.49}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.35}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.37}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.35}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.55}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/chlorophyllValues
# None
# modify_content
# {'value': [[{'measure': {'value': 0.3}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.49}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.35}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.37}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.35}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.55}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 0.3}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.49}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.35}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.37}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.35}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 0.55}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 8.16}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 9.38}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.69}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.75}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.6}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.71}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/OrganicMatterSensorValues
# None
# modify_content
# {'value': [[{'measure': {'value': 8.16}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 9.38}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.69}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.75}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.6}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.71}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 8.16}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 9.38}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.69}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.75}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.6}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 8.71}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 116.02}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 73.5}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 58.13}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 60.26}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 39.9}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 65.27}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/polyethyleneValues
# None
# modify_content
# {'value': [[{'measure': {'value': 116.02}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 73.5}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 58.13}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 60.26}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 39.9}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 65.27}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 116.02}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 73.5}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 58.13}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 60.26}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 39.9}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 65.27}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 1274.76}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 308.39}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 41.09}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 31.98}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 649.85}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 47.47}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:001/attrs/transparencyValues
# None
# modify_content
# {'value': [[{'measure': {'value': 1274.76}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 308.39}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 41.09}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 31.98}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 649.85}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 47.47}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 1274.76}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 308.39}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 41.09}, 'depth': {'value': -0.4, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 31.98}, 'depth': {'value': -0.8, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 649.85}, 'depth': {'value': -1.2000000000000002, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}, {'measure': {'value': 47.47}, 'depth': {'value': -1.6, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# CTD-E10
# {'id': 'urn:ngsi-ld:TurbiditySensor:009', 'identifier': {'type': 'Property', 'value': 'TurbiditySensor:009'}, 'type': 'TurbiditySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Los Nietos, Cartagena', 'postalCode': '30383'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.65, -0.78]}}, 'controlledProperty': {'type': 'Property', 'value': 'turbidity'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E10'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:010'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'turbidityValues': [[{'measure': {'value': 7.35, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 7.59, 'unitCode': 'NTU'}, 'depth': {'value': -1.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}, {'measure': {'value': 8.25, 'unitCode': 'NTU'}, 'depth': {'value': -2.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:010 sensor', 'type': 'Subscription', 'entities': [{'type': 'TurbiditySensor'}], 'watchedAttributes': ['turbidityValues'], 'notification': {'attributes': ['turbidityValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TurbiditySensor:009', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TurbiditySensor:009%22'}
# <Response [201]>
# ...
# <Response [201]>
# {'id': 'urn:ngsi-ld:PhSensor:019', 'identifier': {'type': 'Property', 'value': 'PhSensor:019'}, 'type': 'PhSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Saladar de Lo Poyo, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.66, -0.8]}}, 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'pHValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'PhSensor'}], 'watchedAttributes': ['pHValues'], 'notification': {'attributes': ['pHValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PhSensor:019', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PhSensor:019%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:ChlorophyllSensor:019', 'identifier': {'type': 'Property', 'value': 'ChlorophyllSensor:019'}, 'type': 'ChlorophyllSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Saladar de Lo Poyo, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.66, -0.8]}}, 'controlledProperty': {'type': 'Property', 'value': 'chlorophyll'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'chlorophyllValues': [[{'measure': {'value': 10.98}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'ChlorophyllSensor'}], 'watchedAttributes': ['chlorophyllValues'], 'notification': {'attributes': ['chlorophyllValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:ChlorophyllSensor:019', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22ChlorophyllSensor:019%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:OrganicMatterSensor:019', 'identifier': {'type': 'Property', 'value': 'OrganicMatterSensor:019'}, 'type': 'OrganicMatterSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Saladar de Lo Poyo, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.66, -0.8]}}, 'controlledProperty': {'type': 'Property', 'value': 'OrganicMatterSensor'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'OrganicMatterSensorValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'OrganicMatterSensor'}], 'watchedAttributes': ['OrganicMatterSensorValues'], 'notification': {'attributes': ['OrganicMatterSensorValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:OrganicMatterSensor:019', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22OrganicMatterSensor:019%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PolyethyleneSensor:019', 'identifier': {'type': 'Property', 'value': 'PolyethyleneSensor:019'}, 'type': 'PolyethyleneSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Saladar de Lo Poyo, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.66, -0.8]}}, 'controlledProperty': {'type': 'Property', 'value': 'polyethylene'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'polyethyleneValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'PolyethyleneSensor'}], 'watchedAttributes': ['polyethyleneValues'], 'notification': {'attributes': ['polyethyleneValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PolyethyleneSensor:019', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PolyethyleneSensor:019%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:TransparencySensor:019', 'identifier': {'type': 'Property', 'value': 'TransparencySensor:019'}, 'type': 'TransparencySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Saladar de Lo Poyo, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.66, -0.8]}}, 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Buoy:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'transparencyValues': [[{'depth': {'value': -99, 'unitCode': 'MTR'}, 'value': {'value': -99, 'unitCode': 'CEL'}, 'observedAt': '2016-08-02T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Buoy:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'TransparencySensor'}], 'watchedAttributes': ['transparencyValues'], 'notification': {'attributes': ['transparencyValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TransparencySensor:019', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TransparencySensor:019%22'}
# <Response [201]>
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# 2016-08-04T00:00:00Z
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# ['profundidad_0.0', 'profundidad_-1.0', 'profundidad_-2.0']
# 204
# [{'measure': {'value': 0.5, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/turbidityValues
# None
# modify_content
# {'value': [[{'measure': {'value': 0.5, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 0.5, 'unitCode': 'NTU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 45.3, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/salinityValues
# None
# modify_content
# {'value': [[{'measure': {'value': 45.3, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 45.3, 'unitCode': 'PSU'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 28.99, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/temperatureValues
# None
# modify_content
# {'value': [[{'measure': {'value': 28.99, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 28.99, 'unitCode': 'CEL'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/conductivityValues
# None
# modify_content
# {'value': [[{'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 7.19, 'unitCode': 'microseconds/cm'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 5.83}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/oxygenValues
# None
# modify_content
# {'value': [[{'measure': {'value': 5.83}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 5.83}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 8.73, 'unitCode': 'pH'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/pHValues
# None
# modify_content
# {'value': [[{'measure': {'value': 8.73, 'unitCode': 'pH'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 8.73, 'unitCode': 'pH'}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 0.33}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/chlorophyllValues
# None
# modify_content
# {'value': [[{'measure': {'value': 0.33}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 0.33}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 11.91}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/OrganicMatterSensorValues
# None
# modify_content
# {'value': [[{'measure': {'value': 11.91}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 11.91}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 85.52}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/polyethyleneValues
# None
# modify_content
# {'value': [[{'measure': {'value': 85.52}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 85.52}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# [{'measure': {'value': 21.7}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]
# 2023-08-24T00:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Buoy:009/attrs/transparencyValues
# None
# modify_content
# {'value': [[{'measure': {'value': 21.7}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204
# 2023-08-24T00:00:00Z
# modify_content
# {'value': '2023-08-24T00:00:00Z'}
# 204
# None
# modify_content
# {'value': [[{'measure': {'value': 21.7}, 'depth': {'value': 0.0, 'unitCode': 'MTR'}, 'observedAt': '2023-08-24T00:00:00Z'}]]}
# 204

# %%
maper_rambla_id = {
    "06A01": "urn:ngsi-ld:Ravine:001",
    "06A02": "urn:ngsi-ld:Ravine:002",
    "06A03": "urn:ngsi-ld:Ravine:003",
    "06A04": "urn:ngsi-ld:Ravine:004",
    "06A05": "urn:ngsi-ld:Ravine:005",
    "06A06": "urn:ngsi-ld:Ravine:006",
    "06A18": "urn:ngsi-ld:Ravine:007",
    "06A19": "urn:ngsi-ld:Ravine:008",
    "06P02": "urn:ngsi-ld:Ravine:009",
    "06P04": "urn:ngsi-ld:Ravine:010",
    "06P05": "urn:ngsi-ld:Ravine:011",
    "01M02": "urn:ngsi-ld:Ravine:012",
    "06B01": "urn:ngsi-ld:Ravine:013"
}

diccionario_info_ramblas = {
    "06A01": {
        "description": "Marco de control 06A01 en la puebla , rambla del Albujón",
        "locality": "RM-F35, La Puebla, Cartagena",
        "postalCode": "30395",
        "location": [37.7207, -0.9144],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12",
        "section": 5,
        "nextSection": maper_rambla_id["06A18"],
        "previousSection": maper_rambla_id["06A02"],
    },
    "06A02": {
        "description": "Marco de control 06A02 en Pozo Estrecho, rambla del Albujón",
        "locality": "Pozo Estrecho, Cartagena",
        "postalCode": "30594",
        "location": [37.7239, -0.9793],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12",
        "section": 4,
        "nextSection": maper_rambla_id["06A01"],
        "previousSection": maper_rambla_id["06A03"],
    },
    "06A03": {
        "description": "Marco de control 06A03 rambla del Albujón",
        "locality": "Rambla de El Albujón, Cartagena",
        "postalCode": "30330",
        "location": [37.7213, -1.0491],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12",
        "section": 3,
        "nextSection": maper_rambla_id["06A02"],
        "previousSection": maper_rambla_id["06A04"],
    },
    "06A04": {
        "description": "Marco de control 06A04 en el Estrecho, rambla del Albujón",
        "locality": "Estrecho de Fuente Álamo, Cartagena",
        "postalCode": "30332",
        "location": [37.7259, -1.1098],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12",
        "section": 2,
        "nextSection": maper_rambla_id["06A03"],
        "previousSection": maper_rambla_id["06A05"]+","+maper_rambla_id["06A06"],
    },
    "06A05": {
        "description": "Marco de control 06A05 en Fuente Álamo, rambla del Albujón",
        "locality": "Fuente Álamo, Murcia",
        "postalCode": "30320",
        "location": [37.7247, -1.1721],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12",
        "section": 1,
        "nextSection": maper_rambla_id["06A04"],
        "previousSection": None,
    },
    "06A06": {
        "description": "Marco de control 06A06 en Los Cegarras, rambla de la Murta",
        "locality": "Cabecico del Rey, Murcia",
        "postalCode": "30154",
        "location": [37.7541, -1.1443],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12",
        "section": 1,
        "nextSection": maper_rambla_id["06A04"],
        "previousSection": None,
    },
    "06A18": {
        "description": "Desembocadura 06A05 Rambla del Albujón",
        "locality": "Bahía Bella, Cartagena",
        "postalCode": "30368",
        "location": [37.7163, -0.8610],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12",
        "section": 6,
        "nextSection": None,
        "previousSection": maper_rambla_id["06A01"],
    },
    "06A19": {
        "description": "Marco de control en Rambla de la Maraña- Balsicas",
        "locality": "Los Camachos, Cartagena",
        "postalCode": "30592",
        "location": [37.7953, -0.9415],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06P02": {
        "description": "Marco de control 06P02 en Rambla de la Maraña- Balsicas",
        "locality": "Torre Pacheco, Murcia",
        "postalCode": "30708",
        "location": [37.7492, -0.9921],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06P04": {
        "description": "Marco de control 06P04 en Torre Pacheco",
        "locality": "La Murta-Carrascoy, Murcia",
        "postalCode": "30153",
        "location": [37.8270, -1.2107],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06P05": {
        "description": "Marco de control 06P04 en San Javier (El Mirador)",
        "locality": "El Mirador, San Javier, Murcia",
        "postalCode": "30592",
        "location": [37.8359, -0.8757],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "01M02": {
        "description": "Estación Meteoro-Hidrológica 01M02 el Relojero (AMETSE)",
        "locality": "El Relojero, La Alberca, Murcia",
        "postalCode": "30155",
        "location": [37.9136, -1.1190],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06B01": {
        "description": "Elevación 06B01 el Albujón",
        "locality": "Bahía bellas, Los Alcazares, Cartagena",
        "postalCode": "30368",
        "location": [37.7175, -0.8598],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06B01L03",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    }
}

# %% [markdown]
# ## Parquet

# %%
# Especifica la ruta de la carpeta principal
carpeta = "C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}


# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    df_total = pd.DataFrame()
    archivos_parquet = glob.glob(os.path.join(carpeta+carpeta_actual, "*.parquet"))
    for archivo in archivos_parquet:
        print(archivo)
        df_temporal = pd.read_parquet(archivo)
        tabla = pq.ParquetFile(archivo)

        print(tabla.metadata)
        print("-"*10)
        
        #df_temporal.to_csv(archivo.split(".")[0]+"from_parquet.csv", index=False)
        
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="inner")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")

import numpy as np
for key, df in dfs.items():
    numeric_cols = df.columns.copy()
    numeric_cols = numeric_cols.drop("Date")
    df.replace('-', float('nan'), inplace=True)
    df.replace("null", float('nan'), inplace=True)
    df[numeric_cols] = df[numeric_cols].astype(float)
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")
# Out:
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/01M02-Relojero\01M02D01-Humedad.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EADCF70360>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 574212
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1972
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/01M02-Relojero\01M02D02-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EADB17E250>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 574212
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1996
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/01M02-Relojero\01M02D03-Presion Atmosferica.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EADCF73AB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 574212
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2060
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/01M02-Relojero\01M02D04-Direccion del Viento.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE4668770>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 574212
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2077
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/01M02-Relojero\01M02D09-Velocidad del Viento.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EADEA13FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 574212
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2076
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/01M02-Relojero\01M02P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE4668770>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 574212
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1995
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A01-La Puebla\06A01D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA7B6D490>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 794208
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1959
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A01-La Puebla\06A01P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE4668770>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 778716
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1959
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A01-La Puebla\06A01Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA7B6D490>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 726252
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1916
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A01-La Puebla\06A01U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA83DBAD40>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 805152
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1912
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A02-Pozo Estrecho\06A02D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA92147380>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 817824
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1959
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A02-Pozo Estrecho\06A02P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA7B6D490>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 840336
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1959
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A02-Pozo Estrecho\06A02Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAF84147C0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 638100
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1916
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A02-Pozo Estrecho\06A02U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA83DBAB10>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 728520
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1912
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A03-Rbla Albujon\06A03D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAF5AD4590>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 760812
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1959
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A03-Rbla Albujon\06A03P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA92147380>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 820752
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1959
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A03-Rbla Albujon\06A03Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA83ACB6A0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 688248
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1916
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A03-Rbla Albujon\06A03U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE96BB3D0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 753900
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1911
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A04-El Estrecho\06A04D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAEE792CF0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1996
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A04-El Estrecho\06A04P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAEE792D90>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1995
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A04-El Estrecho\06A04Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA888DC810>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 720516
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1968
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A04-El Estrecho\06A04U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA90E1E070>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1952
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A05-Fuente Alamo\06A05D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA97177FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 604740
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1995
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A05-Fuente Alamo\06A05P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA97177EC0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 604752
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1994
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A05-Fuente Alamo\06A05Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA8883FF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 605028
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1967
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A05-Fuente Alamo\06A05U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE0104950>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 605028
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1951
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A06-Los Cegarras\06A06D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA998DBF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1996
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A06-Los Cegarras\06A06P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE0104950>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1995
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A06-Los Cegarras\06A06Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE1CD4220>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 750444
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1968
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A06-Los Cegarras\06A06U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA9D64BF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1952
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A18-Desemboc Rbla Albujon\06A18D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA22A3FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 219768
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1990
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A18-Desemboc Rbla Albujon\06A18D06-Humedad.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA22A3EC0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 219768
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1916
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A18-Desemboc Rbla Albujon\06A18P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA9D1EFF60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 219768
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1986
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A18-Desemboc Rbla Albujon\06A18Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE0177FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 321036
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1916
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A18-Desemboc Rbla Albujon\06A18U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA8FD729D0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 321036
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1912
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A19-La Marana\06A19D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA9180CFE0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 232968
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1995
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A19-La Marana\06A19P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA9180D170>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 232968
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1993
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A19-La Marana\06A19Q01-Caudal.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA90957F60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 296040
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1967
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06A19-La Marana\06A19U12-Nivel.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA9180D030>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 297204
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1951
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01B01-Volumen Deposito.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA92453FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2039
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01D03-Presion Tuberia Salida Impulsion.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA92453E70>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2167
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01E03-Conductividad Aspiracion.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA9DF9D8F0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2103
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01L01-Nivel sobre Vertedero.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAF07A4AE0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2077
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01L02-Nivel Deposito.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA1453FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2031
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01L03-Nivel Captacion.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA8D1AC040>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2035
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01Q01-Caudal Salida al Mar.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA09A3FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2073
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01Q02-Caudal Salida a RmblAlbujon.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE5037FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 273588
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2123
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06B01-Elevacion El Albujon\06B01Q03-Caudal Salida ElvAlbujon a ElvNarejos.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA0E43FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 275592
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2207
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06P02-Torre Pacheco\06P02D02-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA83348040>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1998
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06P02-Torre Pacheco\06P02P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EA83348130>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1995
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06P04-La Murta\06P04D02-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAA0E43A60>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1998
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06P04-La Murta\06P04P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE47FC450>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 849228
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1994
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06P05-San Javier\06P05D05-Temperatura.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE30A7FB0>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 678168
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1996
# ----------
# C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/06P05-San Javier\06P05P01-Pluviometro.parquet
# <pyarrow._parquet.FileMetaData object at 0x000001EAE47FC450>
#   created_by: parquet-cpp-arrow version 15.0.0
#   num_columns: 2
#   num_rows: 678168
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 1993
# ----------

# %%
import math
import time

def formatMultipleValues(values, unitcode, observedAt, providedBy):
    if len(values) == 0:
        return None
    else:
        result = []
        for i in range(len(values)):
            json_data = {
                "measure": {
                    "value": values[i],
                    "unitCode": unitcode
                },
                "providedBy": providedBy,
                "observedAt": observedAt
            }
            if providedBy is None:
                del json_data["providedBy"]
            if unitcode is None:
                del json_data["measure"]["unitCode"]
            result.append(json_data)
        return result
    
def check_exists(place_to_search, value_to_search, array=False):
    if array:
        return place_to_search[value_to_search][0] if value_to_search in place_to_search else None

    return place_to_search[value_to_search] if value_to_search in place_to_search else None

maper_property_sensor = { "Volumen":"VolumeSensor","Presion":"PressureSensor","Temperatura": "TemperatureSensor", "Presion Atmosferica":"AtmosphericPressureSensor","Direccion del Viento":"WindDirectionSensor","Velocidad del Viento":"WindSpeedSensor" ,"Nivel": "WaterLevelSensor", "Pluviometro":"PrecipitationSensor","Caudal":"WaterFlowSensor", "Humedad":"HumiditySensor","Conductividad":"ConductivitySensor",
}

maper_property_controlled = { "Volumen":"volume","Presion":"pressure","Presion Atmosferica":"atmosphericPressure","Direccion del Viento":"windDirection","Velocidad del Viento":"windSpeed","Temperatura": "temperature", "Nivel": "waterLevel", "Pluviometro":"precipitation","Caudal":"waterFlow", "Humedad":"humidity","Conductividad":"conductivity"
}

maper_property_unitcode = { "Volumen":"m3","Presion":"bar", "Presion Atmosferica":"mbar", "Direccion del Viento":"°","Velocidad del Viento":"m/s","Temperatura": "CEL", "Conductividad": "microseconds/cm", "Nivel": "m", "Pluviometro":"mm","Caudal":"m3/s", "Humedad":"%"
}

maper_property_filename = {
    "Volumen Deposito":"B01-Volumen Depositofrom_parquet.csv","Presion Tuberia Salida Impulsion":"D03-Presion Tuberia Salida Impulsionfrom_parquet.csv","Presion Atmosferica":"D03-Presion Atmosfericafrom_parquet.csv",
    "Direccion del Viento":"D04-Direccion del Vientofrom_parquet.csv","Velocidad del Viento":"D09-Velocidad del Vientofrom_parquet.csv","Temperatura": "D05-Temperaturafrom_parquet.csv", 
    "Nivel": "U12-Nivelfrom_parquet.csv", "Pluviometro":"P01-Pluviometrofrom_parquet.csv","Caudal":"Q01-Caudalfrom_parquet.csv", "Humedad":"D06-Humedadfrom_parquet.csv",
    "Conductividad Aspiracion":"E03-Conductividad Aspiracionfrom_parquet.csv", "Nivel sobre Vertedero":"L01-Nivel sobre Vertederofrom_parquet.csv",
    "Nivel Deposito":"L02-Nivel Depositofrom_parquet.csv","Nivel Captacion": "L03-Nivel Captacionfrom_parquet.csv", "Caudal Salida al Mar": "Q01-Caudal Salida al Marfrom_parquet.csv",
    "Caudal Salida a RmblAlbujon":"Q02-Caudal Salida a RmblAlbujonfrom_parquet.csv", "Caudal Salida ElvAlbujon a ElvNarejos":"Q03-Caudal Salida ElvAlbujon a ElvNarejosfrom_parquet.csv"
}

link_rambla_sensores = {}

num_ramblas = 0

counter_connections = 0

for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    for i in sensores:
        if counters.get(i) is None:
            counters[i] = 0
    print(sensores)
    id_rambla = carpeta.split("-")[0]
    if (id_rambla not in diccionario_info_ramblas):
        continue
    
    id_entity = maper_rambla_id[id_rambla]
    number_entity = id_entity.split(":")[-1]
    for index, row in valorCarpeta.iterrows():
        waterLevel_values = []
        waterFlow_values = []
        counter_connections = counter_connections + 1
        if index == 0:
            measurement_places = {}
            for contador,valorSensor in enumerate(sensores):
                original = valorSensor
                if valorSensor == "Date":
                    continue
                if len(valorSensor.split(" "))>0 and valorSensor not in maper_property_controlled:
                    measurementPlace = " ".join(valorSensor.split(" ")[1:])
                    valorSensor = valorSensor.split(" ")[0]
                    measurement_places[maper_property_controlled[valorSensor]] = measurementPlace
                    if valorSensor not in counters:
                        counters[valorSensor] = 0

                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[valorSensor]}:{str(counters[valorSensor]).zfill(3)}"

                if "Nivel" in valorSensor or "Caudal" in valorSensor:
                    measure_location = None
                    if len(original.split(" "))>0:
                        measure_location = " ".join(original.split(" ")[1:])
                    nuevo_valor = {"measure": {"value": row[original],"unitCode": maper_property_unitcode[valorSensor]}, "place": {"type":"property","value":measure_location},"providedBy": id_sensor,"observedAt": row["Date"]}
                    if measure_location is None:
                        del nuevo_valor["place"]
                    if not math.isnan(row[original]):
                        if "Nivel" in valorSensor:
                            waterLevel_values.append(nuevo_valor)
                        else:
                            waterFlow_values.append(nuevo_valor)
                    continue
                crear_sensor(
                     id=str(counters[valorSensor]).zfill(3),
                     sensor_type=maper_property_sensor[valorSensor],
                     locality=diccionario_info_ramblas[id_rambla]["locality"],
                     postalCode=diccionario_info_ramblas[id_rambla]["postalCode"],
                     location=diccionario_info_ramblas[id_rambla]["location"],
                     controlledProperty=maper_property_controlled[valorSensor],
                     measuredProperty=maper_property_controlled[valorSensor],
                     measureType="multipleValue" if valorSensor == "Caudal" or valorSensor == "Nivel" else "singleValue",
                     measureValue=formatMultipleValues([row[original]],maper_property_unitcode[valorSensor], row["Date"], None) if valorSensor == "Caudal" or valorSensor == "Nivel" else row[original],
                     unitCode=maper_property_unitcode[valorSensor],
                     source=diccionario_info_ramblas[id_rambla]["source"],
                     controlledAsset=id_entity,
                     dateLastValueReported=row["Date"],
                )
                    
                if id_entity not in link_rambla_sensores:
                    link_rambla_sensores[id_entity] = {}
                link_rambla_sensores[id_entity][valorSensor] = id_sensor,
                watched_attributes_value = maper_property_controlled[valorSensor]+"Values" if valorSensor == "Caudal" or valorSensor == "Nivel" else  maper_property_controlled[valorSensor]
                crear_subscription(
                    description="Subscription to get info about " + id_entity + " sensor",
                    entity_type=maper_property_sensor[valorSensor],
                    watched_attributes=[watched_attributes_value],
                    sent_attributes=[watched_attributes_value, "controlledAsset", "measureType"],
                    # TODO Cambiar Id por identifier aqui y en el modelo NGSI-LD y en el required
                    query=f"identifier==%22{maper_property_sensor[valorSensor]}:{str(counters[valorSensor]).zfill(3)}%22",
                    url="http://node-app:3000/historic/"+id_sensor
                )
                counters[valorSensor]+=1
            for column_name,values_collection in zip(["Nivel","Caudal"],[waterLevel_values, waterFlow_values]):
                if(len(values_collection) > 0):
                    crear_sensor(
                     id=str(counters[column_name]).zfill(3),
                     sensor_type=maper_property_sensor[column_name],
                     locality=diccionario_info_ramblas[id_rambla]["locality"],
                     postalCode=diccionario_info_ramblas[id_rambla]["postalCode"],
                     location=diccionario_info_ramblas[id_rambla]["location"],
                     controlledProperty=maper_property_controlled[column_name],
                     measuredProperty=maper_property_controlled[column_name],
                     measureType="multipleValue",
                     measureValue= values_collection,
                     unitCode=maper_property_unitcode[column_name],
                     source=diccionario_info_ramblas[id_rambla]["source"],
                     controlledAsset=id_entity,
                     dateLastValueReported=row["Date"],
                    )
                    
                    if id_entity not in link_rambla_sensores:
                        link_rambla_sensores[id_entity] = {}
                    link_rambla_sensores[id_entity][column_name] = id_sensor,
                    watched_attributes_value = maper_property_controlled[column_name]+"Values" if column_name == "Caudal" or column_name == "Nivel" else  maper_property_controlled[column_name]
                    crear_subscription(
                        description="Subscription to get info about " + id_entity + " sensor",
                        entity_type=maper_property_sensor[column_name],
                        watched_attributes=[watched_attributes_value],
                        sent_attributes=[watched_attributes_value, "controlledAsset", "measureType"],
                        # TODO Cambiar Id por identifier aqui y en el modelo NGSI-LD y en el required
                        query=f"identifier==%22{maper_property_sensor[column_name]}:{str(counters[column_name]).zfill(3)}%22",
                        url="http://node-app:3000/historic/"+id_sensor
                    )
                    counters[column_name]+=1
            
            fecha = row["Date"]
            entities_id[id_entity] = diccionario_info_ramblas[id_rambla]["location"]
            conductivity = next((cadena for cadena in row.index if "Conductividad" in cadena), None)
            pressure = next((cadena for cadena in row.index if "Presion" in cadena), None) if next((cadena for cadena in row.index if "Presion" in cadena), None) != "Presion Atmosferica" else None
            volume = next((cadena for cadena in row.index if "Volumen" in cadena), None)

            crear_rambla(
                id=number_entity,
                dateLastValueReported=fecha,
                description=diccionario_info_ramblas[id_rambla]["description"],
                locality=diccionario_info_ramblas[id_rambla]["locality"],
                postalCode=diccionario_info_ramblas[id_rambla]["postalCode"],
                source=diccionario_info_ramblas[id_rambla]["source"],
                location=diccionario_info_ramblas[id_rambla]["location"],
                temperature=row["Temperatura"] if "Temperatura" in row else None, 
                providedByTemp= check_exists(link_rambla_sensores[id_entity],"Temperatura",array=True),
                obsTemp=fecha,
                precipitation=row["Pluviometro"] if "Pluviometro" in row else None, 
                providedByPrec= check_exists(link_rambla_sensores[id_entity],"Pluviometro",array=True),
                obsPrec=fecha,
                humidity=row["Humedad"] if "Humedad" in row else None, 
                providedByHum= check_exists(link_rambla_sensores[id_entity],"Humedad",array=True),
                obsHum=fecha,
                atmosphericPressure=row["Presion Atmosferica"] if "Presion Atmosferica" in row else None,
                providedByAtPress= check_exists(link_rambla_sensores[id_entity],"Presion Atmosferica",array=True),
                obsAtPress=fecha,
                windSpeed=row["Velocidad del Viento"] if "Velocidad del Viento" in row else None,
                providedBywindSp= check_exists(link_rambla_sensores[id_entity],"Velocidad del Viento",array=True),
                obsWindSp=fecha,
                windDirection=row["Direccion del Viento"] if "Direccion del Viento" in row else None,
                providedByWindDir= check_exists(link_rambla_sensores[id_entity],"Direccion del Viento",array=True),
                obsWindDir=fecha,
                conductivity= row[conductivity] if conductivity != None else None,
                providedByCond= check_exists(link_rambla_sensores[id_entity],"Conductividad",array=True),
                obsCond= fecha,
                volume= row[volume] if volume != None else None,
                providedByVol= check_exists(link_rambla_sensores[id_entity],"Volumen",array=True),
                obsVol= fecha,
                pressure= row[pressure] if pressure != None else None,
                providedByPress= check_exists(link_rambla_sensores[id_entity],"Presion",array=True),
                obsPress= fecha,
                waterFlowValues=[waterFlow_values] if any("Caudal" in cadena for cadena in row.index) else None, 
                waterLevelValues=[waterLevel_values] if any("Nivel" in cadena for cadena in row.index) else None, 
                section=diccionario_info_ramblas[id_rambla]["section"],
                nextSection=diccionario_info_ramblas[id_rambla]["nextSection"],
                measurementsPlaces=measurement_places,
                previousSection=diccionario_info_ramblas[id_rambla]["previousSection"],
                name="Ravine " + id_rambla
            )
            num_ramblas += 1
        elif index == 1:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    print(row["Date"])
                    continue
                
                cabecera_recortada = ""
                if sensores[contador] not in maper_property_sensor:
                    cabecera_recortada = valorSensor.split(" ")[0]
                else:
                    cabecera_recortada = valorSensor

                id_sensor = f"urn:ngsi-ld:{maper_property_sensor[cabecera_recortada]}:{str((counters[cabecera_recortada]-1)).zfill(3)}"

                carpeta_distinta_temp_code = ["06P04-La Murta","06P02-Torre Pacheco","01M02-Relojero"]
                if carpeta in carpeta_distinta_temp_code and valorSensor == "Temperatura":
                    file = id_rambla+"D02-Temperaturafrom_parquet.csv"
                else:
                    if valorSensor == "Humedad" and carpeta == "01M02-Relojero": 
                        file = id_rambla+"D01-Humedadfrom_parquet.csv"
                    else:
                        file = id_rambla+maper_property_filename[valorSensor]
                uploadFileRead(id_sensor, "Ramblas/"+carpeta+"/"+file, maper_property_controlled[cabecera_recortada], [valorSensor], maper_property_unitcode[cabecera_recortada], id_entity, "multipleValue" if "Nivel" in valorSensor or "Caudal" in valorSensor else "singleValue")      
        else:
            time.sleep(80)
            break
# Out:
# 01M02-Relojero
# ['Temperatura', 'Date', 'Humedad', 'Direccion del Viento', 'Pluviometro', 'Presion Atmosferica', 'Velocidad del Viento']
# {'id': 'urn:ngsi-ld:TemperatureSensor:039', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:039'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:012'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:012 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:039', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:039%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:HumiditySensor:000', 'identifier': {'type': 'Property', 'value': 'HumiditySensor:000'}, 'type': 'HumiditySensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'controlledProperty': {'type': 'Property', 'value': 'humidity'}, 'humidity': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': '%'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:012'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:012 sensor', 'type': 'Subscription', 'entities': [{'type': 'HumiditySensor'}], 'watchedAttributes': ['humidity'], 'notification': {'attributes': ['humidity', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:HumiditySensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22HumiditySensor:000%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WindDirectionSensor:000', 'identifier': {'type': 'Property', 'value': 'WindDirectionSensor:000'}, 'type': 'WindDirectionSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'controlledProperty': {'type': 'Property', 'value': 'windDirection'}, 'windDirection': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': '°'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:012'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:012 sensor', 'type': 'Subscription', 'entities': [{'type': 'WindDirectionSensor'}], 'watchedAttributes': ['windDirection'], 'notification': {'attributes': ['windDirection', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WindDirectionSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WindDirectionSensor:000%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:000', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:000'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:012'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:012 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:000%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:AtmosphericPressureSensor:000', 'identifier': {'type': 'Property', 'value': 'AtmosphericPressureSensor:000'}, 'type': 'AtmosphericPressureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'controlledProperty': {'type': 'Property', 'value': 'atmosphericPressure'}, 'atmosphericPressure': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'mbar'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:012'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:012 sensor', 'type': 'Subscription', 'entities': [{'type': 'AtmosphericPressureSensor'}], 'watchedAttributes': ['atmosphericPressure'], 'notification': {'attributes': ['atmosphericPressure', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:AtmosphericPressureSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22AtmosphericPressureSensor:000%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WindSpeedSensor:000', 'identifier': {'type': 'Property', 'value': 'WindSpeedSensor:000'}, 'type': 'WindSpeedSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'controlledProperty': {'type': 'Property', 'value': 'windSpeed'}, 'windSpeed': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'm/s'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:012'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:012 sensor', 'type': 'Subscription', 'entities': [{'type': 'WindSpeedSensor'}], 'watchedAttributes': ['windSpeed'], 'notification': {'attributes': ['windSpeed', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WindSpeedSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WindSpeedSensor:000%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:012', 'identifier': {'type': 'Property', 'value': 'Ravine:012'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Estación Meteoro-Hidrológica 01M02 el Relojero (AMETSE)'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'name': {'type': 'Property', 'value': 'Ravine 01M02'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:039'}}, 'windSpeed': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'm/s', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:WindSpeedSensor:000'}}, 'windDirection': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': '°', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:WindDirectionSensor:000'}}, 'atmosphericPressure': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:AtmosphericPressureSensor:000'}}, 'precipitation': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:000'}}, 'humidity': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z', 'unitCode': '%', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:HumiditySensor:000'}}, 'section': {'value': 1}}
# None
# 204
# 2018-08-21T00:05:00Z
# 204
# 204
# 204
# 204
# 204
# 06A01-La Puebla
# ['Temperatura', 'Date', 'Nivel', 'Pluviometro', 'Caudal']
# {'id': 'urn:ngsi-ld:TemperatureSensor:040', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:040'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'RM-F35, La Puebla, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7207, -0.9144]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2017-02-26T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:040', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:040%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:001', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:001'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'RM-F35, La Puebla, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7207, -0.9144]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-02-26T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:001%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WaterLevelSensor:000', 'identifier': {'type': 'Property', 'value': 'WaterLevelSensor:000'}, 'type': 'WaterLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'RM-F35, La Puebla, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7207, -0.9144]}}, 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'waterLevelValues': [[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:000', 'observedAt': '2017-02-26T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'WaterLevelSensor'}], 'watchedAttributes': ['waterLevelValues'], 'notification': {'attributes': ['waterLevelValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WaterFlowSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WaterLevelSensor:000%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WaterFlowSensor:000', 'identifier': {'type': 'Property', 'value': 'WaterFlowSensor:000'}, 'type': 'WaterFlowSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'RM-F35, La Puebla, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7207, -0.9144]}}, 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:001'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'waterFlowValues': [[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:000', 'observedAt': '2017-02-26T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:001 sensor', 'type': 'Subscription', 'entities': [{'type': 'WaterFlowSensor'}], 'watchedAttributes': ['waterFlowValues'], 'notification': {'attributes': ['waterFlowValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WaterFlowSensor:000', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WaterFlowSensor:000%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:001', 'identifier': {'type': 'Property', 'value': 'Ravine:001'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2017-02-26T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06A01 en la puebla , rambla del Albujón'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'RM-F35, La Puebla, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7207, -0.9144]}}, 'name': {'type': 'Property', 'value': 'Ravine 06A01'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2017-02-26T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:040'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-02-26T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:001'}}, 'waterFlowValues': {'value': [[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:000', 'observedAt': '2017-02-26T00:00:00Z'}]]}, 'waterLevelValues': {'value': [[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:000', 'observedAt': '2017-02-26T00:00:00Z'}]]}, 'nextSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:007'}, 'previousSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:002'}, 'section': {'value': 5}}
# None
# 204
# 2017-02-26T00:05:00Z
# 204
# 204
# 204
# 06A02-Pozo Estrecho
# ['Temperatura', 'Date', 'Nivel', 'Pluviometro', 'Caudal']
# {'id': 'urn:ngsi-ld:TemperatureSensor:041', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:041'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Pozo Estrecho, Cartagena', 'postalCode': '30594'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7239, -0.9793]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 9.1, 'observedAt': '2016-12-19T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:041', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:041%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:002', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:002'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Pozo Estrecho, Cartagena', 'postalCode': '30594'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7239, -0.9793]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-12-19T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:002', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:002%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WaterLevelSensor:001', 'identifier': {'type': 'Property', 'value': 'WaterLevelSensor:001'}, 'type': 'WaterLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Pozo Estrecho, Cartagena', 'postalCode': '30594'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7239, -0.9793]}}, 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:002'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'waterLevelValues': [[{'measure': {'value': 5.28, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:001', 'observedAt': '2016-12-19T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:002 sensor', 'type': 'Subscription', 'entities': [{'type': 'WaterLevelSensor'}], 'watchedAttributes': ['waterLevelValues'], 'notification': {'attributes': ['waterLevelValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WaterFlowSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WaterLevelSensor:001%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:002', 'identifier': {'type': 'Property', 'value': 'Ravine:002'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2016-12-19T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06A02 en Pozo Estrecho, rambla del Albujón'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Pozo Estrecho, Cartagena', 'postalCode': '30594'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7239, -0.9793]}}, 'name': {'type': 'Property', 'value': 'Ravine 06A02'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 9.1, 'observedAt': '2016-12-19T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:041'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-12-19T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:002'}}, 'waterFlowValues': {'value': [[]]}, 'waterLevelValues': {'value': [[{'measure': {'value': 5.28, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:001', 'observedAt': '2016-12-19T00:00:00Z'}]]}, 'nextSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:001'}, 'previousSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:003'}, 'section': {'value': 4}}
# None
# 204
# 2016-12-19T00:05:00Z
# 204
# 204
# 204
# 06A03-Rbla Albujon
# ['Temperatura', 'Date', 'Nivel', 'Pluviometro', 'Caudal']
# {'id': 'urn:ngsi-ld:TemperatureSensor:042', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:042'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Rambla de El Albujón, Cartagena', 'postalCode': '30330'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7213, -1.0491]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 20.4, 'observedAt': '2017-06-12T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:042', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:042%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:003', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:003'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Rambla de El Albujón, Cartagena', 'postalCode': '30330'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7213, -1.0491]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-06-12T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:003', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:003%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WaterLevelSensor:002', 'identifier': {'type': 'Property', 'value': 'WaterLevelSensor:002'}, 'type': 'WaterLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Rambla de El Albujón, Cartagena', 'postalCode': '30330'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7213, -1.0491]}}, 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:003'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'waterLevelValues': [[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:002', 'observedAt': '2017-06-12T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:003 sensor', 'type': 'Subscription', 'entities': [{'type': 'WaterLevelSensor'}], 'watchedAttributes': ['waterLevelValues'], 'notification': {'attributes': ['waterLevelValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WaterFlowSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WaterLevelSensor:002%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:003', 'identifier': {'type': 'Property', 'value': 'Ravine:003'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2017-06-12T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06A03 rambla del Albujón'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Rambla de El Albujón, Cartagena', 'postalCode': '30330'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7213, -1.0491]}}, 'name': {'type': 'Property', 'value': 'Ravine 06A03'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 20.4, 'observedAt': '2017-06-12T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:042'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-06-12T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:003'}}, 'waterFlowValues': {'value': [[]]}, 'waterLevelValues': {'value': [[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:002', 'observedAt': '2017-06-12T00:00:00Z'}]]}, 'nextSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:002'}, 'previousSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:004'}, 'section': {'value': 3}}
# None
# 204
# 2017-06-12T00:05:00Z
# 204
# 204
# 204
# 06A04-El Estrecho
# ['Temperatura', 'Date', 'Nivel', 'Pluviometro', 'Caudal']
# {'id': 'urn:ngsi-ld:TemperatureSensor:043', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:043'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Estrecho de Fuente Álamo, Cartagena', 'postalCode': '30332'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7259, -1.1098]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 12.9, 'observedAt': '2017-03-31T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:043', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:043%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:004', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:004'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Estrecho de Fuente Álamo, Cartagena', 'postalCode': '30332'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7259, -1.1098]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-03-31T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:004', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:004%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WaterLevelSensor:003', 'identifier': {'type': 'Property', 'value': 'WaterLevelSensor:003'}, 'type': 'WaterLevelSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Estrecho de Fuente Álamo, Cartagena', 'postalCode': '30332'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7259, -1.1098]}}, 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'waterLevelValues': [[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:003', 'observedAt': '2017-03-31T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'WaterLevelSensor'}], 'watchedAttributes': ['waterLevelValues'], 'notification': {'attributes': ['waterLevelValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WaterFlowSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WaterLevelSensor:003%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:WaterFlowSensor:001', 'identifier': {'type': 'Property', 'value': 'WaterFlowSensor:001'}, 'type': 'WaterFlowSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Estrecho de Fuente Álamo, Cartagena', 'postalCode': '30332'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7259, -1.1098]}}, 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'measureType': {'type': 'Property', 'value': 'multipleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:004'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'waterFlowValues': [[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:001', 'observedAt': '2017-03-31T00:00:00Z'}]]}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:004 sensor', 'type': 'Subscription', 'entities': [{'type': 'WaterFlowSensor'}], 'watchedAttributes': ['waterFlowValues'], 'notification': {'attributes': ['waterFlowValues', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:WaterFlowSensor:001', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22WaterFlowSensor:001%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:004', 'identifier': {'type': 'Property', 'value': 'Ravine:004'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2017-03-31T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06A04 en el Estrecho, rambla del Albujón'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Estrecho de Fuente Álamo, Cartagena', 'postalCode': '30332'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7259, -1.1098]}}, 'name': {'type': 'Property', 'value': 'Ravine 06A04'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 12.9, 'observedAt': '2017-03-31T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:043'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-03-31T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:004'}}, 'waterFlowValues': {'value': [[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:001', 'observedAt': '2017-03-31T00:00:00Z'}]]}, 'waterLevelValues': {'value': [[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:003', 'observedAt': '2017-03-31T00:00:00Z'}]]}, 'nextSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:003'}, 'previousSection': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:005,urn:ngsi-ld:Ravine:006'}, 'section': {'value': 2}}
# None
# 204
# 2017-03-31T00:05:00Z
# 204
# 204
# 204
# 06A05-Fuente Alamo
# ['Temperatura', 'Date', 'Nivel', 'Pluviometro', 'Caudal']
# {'id': 'urn:ngsi-ld:TemperatureSensor:044', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:044'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Fuente Álamo, Murcia', 'postalCode': '30320'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7247, -1.1721]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-07T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:005'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:005 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:044', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:044%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:005', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:005'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Fuente Álamo, Murcia', 'postalCode': '30320'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7247, -1.1721]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-07T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:005'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# ...
# urn:ngsi-ld:PressureSensor:000
# 204
# 2021-06-30T00:05:00Z
# 204
# 204
# 204
# 204
# 204
# 204
# 204
# 204
# 06P02-Torre Pacheco
# ['Temperatura', 'Pluviometro', 'Date']
# {'id': 'urn:ngsi-ld:TemperatureSensor:048', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:048'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Torre Pacheco, Murcia', 'postalCode': '30708'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7492, -0.9921]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 12.33, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:048', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:048%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:009', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:009'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Torre Pacheco, Murcia', 'postalCode': '30708'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7492, -0.9921]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:009'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:009 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:009', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:009%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:009', 'identifier': {'type': 'Property', 'value': 'Ravine:009'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06P02 en Rambla de la Maraña- Balsicas'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Torre Pacheco, Murcia', 'postalCode': '30708'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7492, -0.9921]}}, 'name': {'type': 'Property', 'value': 'Ravine 06P02'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 12.33, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:048'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:009'}}, 'section': {'value': 1}}
# None
# 204
# 204
# 2016-01-09T00:05:00Z
# 06P04-La Murta
# ['Temperatura', 'Pluviometro', 'Date']
# {'id': 'urn:ngsi-ld:TemperatureSensor:049', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:049'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'La Murta-Carrascoy, Murcia', 'postalCode': '30153'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.827, -1.2107]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': 14.51, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:010'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:010 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:049', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:049%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:010', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:010'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'La Murta-Carrascoy, Murcia', 'postalCode': '30153'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.827, -1.2107]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:010'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:010 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:010', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:010%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:010', 'identifier': {'type': 'Property', 'value': 'Ravine:010'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06P04 en Torre Pacheco'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'La Murta-Carrascoy, Murcia', 'postalCode': '30153'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.827, -1.2107]}}, 'name': {'type': 'Property', 'value': 'Ravine 06P04'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': 14.51, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:049'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:010'}}, 'section': {'value': 1}}
# None
# 204
# 204
# 2016-01-09T00:05:00Z
# 06P05-San Javier
# ['Temperatura', 'Pluviometro', 'Date']
# {'id': 'urn:ngsi-ld:TemperatureSensor:050', 'identifier': {'type': 'Property', 'value': 'TemperatureSensor:050'}, 'type': 'TemperatureSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Mirador, San Javier, Murcia', 'postalCode': '30592'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8359, -0.8757]}}, 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2017-08-25T00:00:00Z', 'unitCode': 'CEL'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:011'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:011 sensor', 'type': 'Subscription', 'entities': [{'type': 'TemperatureSensor'}], 'watchedAttributes': ['temperature'], 'notification': {'attributes': ['temperature', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:TemperatureSensor:050', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22TemperatureSensor:050%22'}
# <Response [201]>
# {'id': 'urn:ngsi-ld:PrecipitationSensor:011', 'identifier': {'type': 'Property', 'value': 'PrecipitationSensor:011'}, 'type': 'PrecipitationSensor', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Mirador, San Javier, Murcia', 'postalCode': '30592'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8359, -0.8757]}}, 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-08-25T00:00:00Z', 'unitCode': 'mm'}, 'measureType': {'type': 'Property', 'value': 'singleValue'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01'}, 'controlledAsset': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:011'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld'}
# <Response [201]>
# {'description': 'Subscription to get info about urn:ngsi-ld:Ravine:011 sensor', 'type': 'Subscription', 'entities': [{'type': 'PrecipitationSensor'}], 'watchedAttributes': ['precipitation'], 'notification': {'attributes': ['precipitation', 'controlledAsset', 'measureType'], 'format': 'normalized', 'endpoint': {'uri': 'http://node-app:3000/historic/urn:ngsi-ld:PrecipitationSensor:011', 'accept': 'application/json'}}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'q': 'identifier==%22PrecipitationSensor:011%22'}
# <Response [201]>
# ***************
# {'id': 'urn:ngsi-ld:Ravine:011', 'identifier': {'type': 'Property', 'value': 'Ravine:011'}, 'type': 'Ravine', 'dateLastValueReported': {'type': 'Property', 'value': '2017-08-25T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Marco de control 06P04 en San Javier (El Mirador)'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Mirador, San Javier, Murcia', 'postalCode': '30592'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8359, -0.8757]}}, 'name': {'type': 'Property', 'value': 'Ravine 06P05'}, '@context': 'https://raw.githubusercontent.com/mariete1223/MarMenor/main/data_models_description/datamodels.context-ngsi.jsonld', 'temperature': {'type': 'Property', 'value': -99, 'observedAt': '2017-08-25T00:00:00Z', 'unitCode': 'CEL', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:TemperatureSensor:050'}}, 'precipitation': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-08-25T00:00:00Z', 'unitCode': 'mm', 'providedBy': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PrecipitationSensor:011'}}, 'section': {'value': 1}}
# None
# 204
# 204
# 2017-08-25T00:05:00Z

# %%
import os
import glob
import pandas as pd

# Especifica la ruta de la carpeta principal
carpeta = "C:/Users/marie/OneDrive/Escritorio/Antiguo ordenador/Universidad/Master 1º/TFM/NGSI-LD/marMenorDockerCompose/node-app/historicData/SAIHdatasActualizados/Ramblas/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}


# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    df_total = pd.DataFrame()
    archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))

    archivos_csv = [archivo for archivo in archivos_csv if "parquet" not in archivo]
    for archivo in archivos_csv:
    
        df_temporal = pd.read_csv(archivo)
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="inner")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")

# %%
import math
import time

def formatMultipleValues(values, unitcode, observedAt, providedBy):
    if len(values) == 0:
        return None
    else:
        result = []
        for i in range(len(values)):
            json_data = {
                "measure": {
                    "value": values[i],
                    "unitCode": unitcode
                },
                "providedBy": providedBy,
                "observedAt": observedAt
            }
            if providedBy is None:
                del json_data["providedBy"]
            if unitcode is None:
                del json_data["measure"]["unitCode"]
            result.append(json_data)
        return result
    
def check_exists(place_to_search, value_to_search, array=False):
    if array:
        return place_to_search[value_to_search][0] if value_to_search in place_to_search else None

    return place_to_search[value_to_search] if value_to_search in place_to_search else None

maper_property_sensor = { "Volumen":"VolumeSensor","Presion":"PressureSensor","Temperatura": "TemperatureSensor", "Presion Atmosferica":"AtmosphericPressureSensor","Direccion del Viento":"WindDirectionSensor","Velocidad del Viento":"WindSpeedSensor" ,"Nivel": "WaterLevelSensor", "Pluviometro":"PrecipitationSensor","Caudal":"WaterFlowSensor", "Humedad":"HumiditySensor","Conductividad":"ConductivitySensor",
}

maper_property_controlled = { "Volumen":"volume","Presion":"pressure","Presion Atmosferica":"atmosphericPressure","Direccion del Viento":"windDirection","Velocidad del Viento":"windSpeed","Temperatura": "temperature", "Nivel": "waterLevel", "Pluviometro":"precipitation","Caudal":"waterFlow", "Humedad":"humidity","Conductividad":"conductivity"
}

maper_property_unitcode = { "Volumen":"m3","Presion":"bar", "Presion Atmosferica":"mbar", "Direccion del Viento":"°","Velocidad del Viento":"m/s","Temperatura": "CEL", "Conductividad": "microseconds/cm", "Nivel": "m", "Pluviometro":"mm","Caudal":"m3/s", "Humedad":"%"
}

link_rambla_sensores = {}

num_ramblas = 0

counter_connections = 0

for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    for i in sensores:
        if counters.get(i) is None:
            counters[i] = 0
    id_rambla = carpeta.split("-")[0]
    if (id_rambla not in diccionario_info_ramblas):
        continue
    
    id_entity = maper_rambla_id[id_rambla]
    number_entity = id_entity.split(":")[-1]
    counter_connections = counter_connections + 1
    waterLevel_values = []
    waterFlow_values = []
    for contador,valorSensor in enumerate(sensores):    
        original = valorSensor
        if valorSensor == "Date":
            continue
        if len(valorSensor.split(" "))>0 and valorSensor not in maper_property_controlled:
            measurementPlace = " ".join(valorSensor.split(" ")[1:])
            valorSensor = valorSensor.split(" ")[0]
            measurement_places[maper_property_controlled[valorSensor]] = measurementPlace
            if valorSensor not in counters:
                counters[valorSensor] = 0

        id_sensor = f"urn:ngsi-ld:{maper_property_sensor[valorSensor]}:{str((counters[valorSensor]-1)).zfill(3)}"

        last_value = valorCarpeta[original].iloc[-1]
        last_date = valorCarpeta["Date"].iloc[-1]

        if "Nivel" in valorSensor or "Caudal" in valorSensor:
            measure_location = None
            if len(original.split(" "))>0:
                measure_location = " ".join(original.split(" ")[1:])
            nuevo_valor = {"measure": {"value": last_value,"unitCode": maper_property_unitcode[valorSensor]}, "place": {"type":"property","value":measure_location},"providedBy": id_sensor,"observedAt": last_date}
            if measure_location is None:
                del nuevo_valor["place"]
            if "Nivel" in valorSensor:
                waterLevel_values.append(nuevo_valor)
            else:
                waterFlow_values.append(nuevo_valor)
        else:
            print(last_value)
            print(last_date)
            print("http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/"+maper_property_controlled[valorSensor])
            modify_entity(
                value=last_value,
                observedAt=last_date,
                url="http://localhost:1026/ngsi-ld/v1/entities/"+id_sensor+"/attrs/"+maper_property_controlled[valorSensor]
            )
            modify_entity(
                value=last_date,
                observedAt=None,
                url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/dateLastValueReported"
            )
            modify_entity(
                place= measurement_places[maper_property_controlled[valorSensor]] if maper_property_controlled[valorSensor] in measurement_places else None,
                value=last_value,
                observedAt=last_date,
                url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/"+maper_property_controlled[valorSensor]
            )
            time.sleep(1)

    for column_name,values_collection in zip(["Nivel","Caudal"],[waterLevel_values, waterFlow_values]):
        if(len(values_collection) > 0):
            print(values_collection)
            modify_entity(
                multipleValue=[values_collection],
                value=None,
                observedAt=None,
                url="http://localhost:1026/ngsi-ld/v1/entities/"+id_sensor+"/attrs/"+maper_property_controlled[valorSensor]+"Values",
            )
            modify_entity(
                value=last_date,
                observedAt=None,
                url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/dateLastValueReported"
            )
            modify_entity(
                    multipleValue=[values_collection],
                    value=None,
                    observedAt=None,
                    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_entity+"/attrs/"+maper_property_controlled[valorSensor]+"Values",
            )
# Out:
# 01M02-Relojero
# 17.28
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:012/attrs/temperature
# 17.28
# modify_content
# {'value': 17.28, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 17.28
# modify_content
# {'value': 17.28, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 52.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:012/attrs/humidity
# 52.0
# modify_content
# {'value': 52.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 52.0
# modify_content
# {'value': 52.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 315.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:012/attrs/windDirection
# 315.0
# modify_content
# {'value': 315.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 315.0
# modify_content
# {'value': 315.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:012/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 1016.2
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:012/attrs/atmosphericPressure
# 1016.2
# modify_content
# {'value': 1016.2, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 1016.2
# modify_content
# {'value': 1016.2, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 6.259
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:012/attrs/windSpeed
# 6.259
# modify_content
# {'value': 6.259, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 6.259
# modify_content
# {'value': 6.259, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 06A01-La Puebla
# 20.9
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:001/attrs/temperature
# 20.9
# modify_content
# {'value': 20.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.9
# modify_content
# {'value': 20.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:001/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.148, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.148, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.148, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.085, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.085, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.085, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A02-Pozo Estrecho
# 20.8
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:002/attrs/temperature
# 20.8
# modify_content
# {'value': 20.8, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.8
# modify_content
# {'value': 20.8, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:002/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A03-Rbla Albujon
# 20.7
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:003/attrs/temperature
# 20.7
# modify_content
# {'value': 20.7, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.7
# modify_content
# {'value': 20.7, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:003/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A04-El Estrecho
# 20.9
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:004/attrs/temperature
# 20.9
# modify_content
# {'value': 20.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.9
# modify_content
# {'value': 20.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:004/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A05-Fuente Alamo
# 20.5
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:005/attrs/temperature
# 20.5
# modify_content
# {'value': 20.5, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.5
# modify_content
# {'value': 20.5, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:005/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A06-Los Cegarras
# 20.9
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:006/attrs/temperature
# 20.9
# modify_content
# {'value': 20.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.9
# modify_content
# {'value': 20.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:006/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A18-Desemboc Rbla Albujon
# 21.1
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:007/attrs/temperature
# 21.1
# modify_content
# {'value': 21.1, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 21.1
# modify_content
# {'value': 21.1, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 42.9
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:007/attrs/humidity
# 42.9
# modify_content
# {'value': 42.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 42.9
# modify_content
# {'value': 42.9, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:007/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.029, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.029, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.029, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0554, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0554, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0554, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06A19-La Marana
# 20.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:008/attrs/temperature
# 20.0
# modify_content
# {'value': 20.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 20.0
# modify_content
# {'value': 20.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:008/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': ''}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06B01-Elevacion El Albujon
# 1.72
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:013/attrs/pressure
# 1.72
# modify_content
# {'value': 1.72, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 1.72
# modify_content
# {'value': 1.72, 'observedAt': '2024-02-12T19:00:00Z', 'measurementPlace': {'value': 'Tuberia Salida Impulsion'}}
# 204
# 2828.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:013/attrs/volume
# 2828.0
# modify_content
# {'value': 2828.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 2828.0
# modify_content
# {'value': 2828.0, 'observedAt': '2024-02-12T19:00:00Z', 'measurementPlace': {'value': 'Deposito'}}
# 204
# 4620.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:013/attrs/conductivity
# 4620.0
# modify_content
# {'value': 4620.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 4620.0
# modify_content
# {'value': 4620.0, 'observedAt': '2024-02-12T19:00:00Z', 'measurementPlace': {'value': 'Aspiracion'}}
# 204
# [{'measure': {'value': 2.49, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'Deposito'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'sobre Vertedero'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 2.53, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'Captacion'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 2.49, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'Deposito'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'sobre Vertedero'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 2.53, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'Captacion'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 2.49, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'Deposito'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'sobre Vertedero'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 2.53, 'unitCode': 'm'}, 'place': {'type': 'property', 'value': 'Captacion'}, 'providedBy': 'urn:ngsi-ld:WaterLevelSensor:006', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# [{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida al Mar'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida a RmblAlbujon'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0833, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida ElvAlbujon a ElvNarejos'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida al Mar'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida a RmblAlbujon'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0833, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida ElvAlbujon a ElvNarejos'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# None
# modify_content
# {'value': [[[{'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida al Mar'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida a RmblAlbujon'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}, {'measure': {'value': 0.0833, 'unitCode': 'm3/s'}, 'place': {'type': 'property', 'value': 'Salida ElvAlbujon a ElvNarejos'}, 'providedBy': 'urn:ngsi-ld:WaterFlowSensor:003', 'observedAt': '2024-02-12T19:00:00Z'}]]]}
# 204
# 06P02-Torre Pacheco
# 21.24
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:009/attrs/temperature
# 21.24
# modify_content
# {'value': 21.24, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 21.24
# modify_content
# {'value': 21.24, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:009/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 06P04-La Murta
# 19.14
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:010/attrs/temperature
# 19.14
# modify_content
# {'value': 19.14, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 19.14
# modify_content
# {'value': 19.14, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:010/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 06P05-San Javier
# 19.7
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:011/attrs/temperature
# 19.7
# modify_content
# {'value': 19.7, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 19.7
# modify_content
# {'value': 19.7, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# 2024-02-12T19:00:00Z
# http://localhost:1026/ngsi-ld/v1/entities/urn:ngsi-ld:Ravine:011/attrs/precipitation
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204
# 2024-02-12T19:00:00Z
# modify_content
# {'value': '2024-02-12T19:00:00Z'}
# 204
# 0.0
# modify_content
# {'value': 0.0, 'observedAt': '2024-02-12T19:00:00Z'}
# 204

# %%
for entity_id, location in entities_id.items():
    close_entities = search_close_entities(location[0], location[1],entity_id)
    print(entity_id)
    create_attribute(
        multipleValue=[{"type":"Relationship","object": close_entity} for close_entity in close_entities],
        value=None,
        observedAt=None,
        url="http://localhost:1026/ngsi-ld/v1/entities/"+entity_id+"/attrs",
        newAttributeName="closeMeasurements"
    )
# Out:
# urn:ngsi-ld:PiezometricPoint:000
# urn:ngsi-ld:PiezometricPoint:001
# urn:ngsi-ld:PiezometricPoint:002
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# c:\Users\marie\OneDrive\Escritorio\Antiguo ordenador\Universidad\Master 1º\TFM\NGSI-LD\datos\script_start_up.ipynb Cell 30 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> close_entities = search_close_entities(location[0], location[1],entity_id)
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> print(entity_id)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> create_attribute(
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=4'>5</a>     multipleValue=[{"type":"Relationship","object": close_entity} for close_entity in close_entities],
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a>     value=None,
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=6'>7</a>     observedAt=None,
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=7'>8</a>     url="http://localhost:1026/ngsi-ld/v1/entities/"+entity_id+"/attrs",
#       <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=8'>9</a>     newAttributeName="closeMeasurements"
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=9'>10</a> )
#
# c:\Users\marie\OneDrive\Escritorio\Antiguo ordenador\Universidad\Master 1º\TFM\NGSI-LD\datos\script_start_up.ipynb Cell 30 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=19'>20</a> else:
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=20'>21</a>     modify_content = {
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=21'>22</a>         newAttributeName: {
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=22'>23</a>             "value": value,
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=23'>24</a>             "observedAt": observedAt
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=24'>25</a>         }
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=25'>26</a>     }
# ---> <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=27'>28</a> response = requests.post(url, headers=headers, json=modify_content)
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=28'>29</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/marie/OneDrive/Escritorio/Antiguo%20ordenador/Universidad/Master%201%C2%BA/TFM/NGSI-LD/datos/script_start_up.ipynb#X43sZmlsZQ%3D%3D?line=29'>30</a>     if response.status_code != 204:
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\marie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
